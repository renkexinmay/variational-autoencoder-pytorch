# %% [markdown]
# <a href="https://colab.research.google.com/github/renkexinmay/Pytorch/blob/master/Variational%20Autoencoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # VAE for MNIST clustering and generation
#
# The goal of this notebook is to explore some recent works dealing with variational auto-encoder (VAE).
#
# We will use MNIST dataset and a basic VAE architecture.

# %%
# to install pytorch on colab
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import transforms
from torchvision.utils import save_image

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics.cluster import normalized_mutual_info_score

def show(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)), interpolation='nearest')

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Create a directory if not exists
sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %%
batch_size = 128
#to be modified
data_dir = '/content/drive/My Drive'
# MNIST dataset
dataset = torchvision.datasets.MNIST(root=data_dir,
                                     train=True,
                                     transform=transforms.ToTensor(),
                                     download=True)

# Data loader
data_loader = torch.utils.data.DataLoader(dataset=dataset,
                                          batch_size=batch_size, 
                                          shuffle=True)

test_loader = torch.utils.data.DataLoader(
    torchvision.datasets.MNIST(data_dir, train=False, download=True, transform=transforms.ToTensor()),
    batch_size=10, shuffle=False)

# %% [markdown]
# # Variational Autoencoders
#
# Consider a latent variable model with a data variable $x\in \mathcal{X}$ and a latent variable $z\in \mathcal{Z}$, $p(z,x) = p(z)p_\theta(x|z)$. Given the data $x_1,\dots, x_n$, we want to train the model by maximizing the marginal log-likelihood:
# \begin{eqnarray*}
# \mathcal{L} = \mathbf{E}_{p_d(x)}\left[\log p_\theta(x)\right]=\mathbf{E}_{p_d(x)}\left[\log \int_{\mathcal{Z}}p_{\theta}(x|z)p(z)dz\right],
#   \end{eqnarray*}
#   where $p_d$ denotes the empirical distribution of $X$: $p_d(x) =\frac{1}{n}\sum_{i=1}^n \delta_{x_i}(x)$.
#
#  To avoid the (often) difficult computation of the integral above, the idea behind variational methods is to instea maximize a lower bound to the log-likelihood:
#   \begin{eqnarray*}
# \mathcal{L} \geq L(p_\theta(x|z),q(z|x)) =\mathbf{E}_{p_d(x)}\left[\mathbf{E}_{q(z|x)}\left[\log p_\theta(x|z)\right]-\mathrm{KL}\left( q(z|x)||p(z)\right)\right].
#   \end{eqnarray*}
#   Any choice of $q(z|x)$ gives a valid lower bound. Variational autoencoders replace the variational posterior $q(z|x)$ by an inference network $q_{\phi}(z|x)$ that is trained together with $p_{\theta}(x|z)$ to jointly maximize $L(p_\theta,q_\phi)$. The variational posterior $q_{\phi}(z|x)$ is also called the encoder and the generative model $p_{\theta}(x|z)$, the decoder or generator.
#
# The first term $\mathbf{E}_{q(z|x)}\left[\log p_\theta(x|z)\right]$ is the negative reconstruction error. Indeed under a gaussian assumption i.e. $p_{\theta}(x|z) = \mathcal{N}(\mu_{\theta}(z), 1)$ the term $\log p_\theta(x|z)$ reduced to $\propto \|x-\mu_\theta(z)\|^2$, which is often used in practice. The term $\mathrm{KL}\left( q(z|x)||p(z)\right)$ can be seen as a regularization term, where the variational posterior $q_\phi(z|x)$ should be matched to the prior $p(z)= \mathcal{N}(0,1)$.
#
# Variational Autoencoders were introduced by [Kingma and Welling](https://arxiv.org/abs/1312.6114), see also [Doersch](https://arxiv.org/abs/1606.05908) for a tutorial.
#
# There are vairous examples of VAE in pytorch available [here](https://github.com/pytorch/examples/tree/master/vae) or [here](https://github.com/yunjey/pytorch-tutorial/blob/master/tutorials/03-advanced/variational_autoencoder/main.py#L38-L65). The code below is taken from this last source.

# %%
# Hyper-parameters
image_size = 784
h_dim = 400
z_dim = 20
num_epochs = 15
learning_rate = 1e-3

# VAE model
class VAE(nn.Module):
    def __init__(self, image_size=784, h_dim=400, z_dim=20):
        super(VAE, self).__init__()
        self.fc1 = nn.Linear(image_size, h_dim)
        self.fc2 = nn.Linear(h_dim, z_dim)
        self.fc3 = nn.Linear(h_dim, z_dim)
        self.fc4 = nn.Linear(z_dim, h_dim)
        self.fc5 = nn.Linear(h_dim, image_size)
        
    def encode(self, x):
        h = F.relu(self.fc1(x))
        return self.fc2(h), self.fc3(h)
    
    def reparameterize(self, mu, log_var):
        std = torch.exp(log_var/2)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z):
        h = F.relu(self.fc4(z))
        return torch.sigmoid(self.fc5(h))
    
    def forward(self, x):
        mu, log_var = self.encode(x)
        z = self.reparameterize(mu, log_var)
        x_reconst = self.decode(z)
        return x_reconst, mu, log_var

model = VAE().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# Here for the loss, instead of MSE for the reconstruction loss, we take BCE. The code below is still from the pytorch tutorial (with minor modifications to avoid warnings!).

# %%
# Start training
for epoch in range(num_epochs):
    for i, (x, _) in enumerate(data_loader):
        # Forward pass
        x = x.to(device).view(-1, image_size)
        x_reconst, mu, log_var = model(x)
        
        # Compute reconstruction loss and kl divergence
        # For KL divergence, see Appendix B in VAE paper
        reconst_loss = F.binary_cross_entropy(x_reconst, x, reduction='sum')
        kl_div = - 0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
        
        # Backprop and optimize
        loss = reconst_loss + kl_div
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (i+1) % 10 == 0:
            print ("Epoch[{}/{}], Step [{}/{}], Reconst Loss: {:.4f}, KL Div: {:.4f}" 
                   .format(epoch+1, num_epochs, i+1, len(data_loader), reconst_loss.item()/batch_size, kl_div.item()/batch_size))
# Out:
# Epoch[1/15], Step [10/469], Reconst Loss: 290.0538, KL Div: 23.0169
# Epoch[1/15], Step [20/469], Reconst Loss: 230.2639, KL Div: 7.9605
# Epoch[1/15], Step [30/469], Reconst Loss: 215.1200, KL Div: 7.5316
# Epoch[1/15], Step [40/469], Reconst Loss: 214.1991, KL Div: 4.8111
# Epoch[1/15], Step [50/469], Reconst Loss: 202.6927, KL Div: 5.5534
# Epoch[1/15], Step [60/469], Reconst Loss: 195.5089, KL Div: 6.3656
# Epoch[1/15], Step [70/469], Reconst Loss: 188.8559, KL Div: 7.6963
# Epoch[1/15], Step [80/469], Reconst Loss: 180.9497, KL Div: 9.4549
# Epoch[1/15], Step [90/469], Reconst Loss: 166.4581, KL Div: 10.8865
# Epoch[1/15], Step [100/469], Reconst Loss: 168.9632, KL Div: 10.5081
# Epoch[1/15], Step [110/469], Reconst Loss: 170.4267, KL Div: 10.9230
# Epoch[1/15], Step [120/469], Reconst Loss: 160.3067, KL Div: 11.3107
# Epoch[1/15], Step [130/469], Reconst Loss: 157.9029, KL Div: 12.8312
# Epoch[1/15], Step [140/469], Reconst Loss: 150.6958, KL Div: 15.0353
# Epoch[1/15], Step [150/469], Reconst Loss: 153.2734, KL Div: 13.9031
# Epoch[1/15], Step [160/469], Reconst Loss: 141.9838, KL Div: 14.2367
# Epoch[1/15], Step [170/469], Reconst Loss: 142.8866, KL Div: 14.6750
# Epoch[1/15], Step [180/469], Reconst Loss: 142.4946, KL Div: 15.2153
# Epoch[1/15], Step [190/469], Reconst Loss: 140.3394, KL Div: 14.7634
# Epoch[1/15], Step [200/469], Reconst Loss: 134.5234, KL Div: 15.5741
# Epoch[1/15], Step [210/469], Reconst Loss: 133.3467, KL Div: 14.5776
# Epoch[1/15], Step [220/469], Reconst Loss: 134.7478, KL Div: 15.8069
# Epoch[1/15], Step [230/469], Reconst Loss: 130.6972, KL Div: 16.7148
# Epoch[1/15], Step [240/469], Reconst Loss: 135.1154, KL Div: 16.4759
# Epoch[1/15], Step [250/469], Reconst Loss: 128.0130, KL Div: 17.5519
# Epoch[1/15], Step [260/469], Reconst Loss: 128.5616, KL Div: 17.5478
# Epoch[1/15], Step [270/469], Reconst Loss: 126.6791, KL Div: 17.6505
# Epoch[1/15], Step [280/469], Reconst Loss: 125.8563, KL Div: 17.4993
# Epoch[1/15], Step [290/469], Reconst Loss: 124.2194, KL Div: 16.9782
# Epoch[1/15], Step [300/469], Reconst Loss: 122.1730, KL Div: 18.7294
# Epoch[1/15], Step [310/469], Reconst Loss: 121.0503, KL Div: 18.6353
# Epoch[1/15], Step [320/469], Reconst Loss: 116.2720, KL Div: 18.2452
# Epoch[1/15], Step [330/469], Reconst Loss: 119.1250, KL Div: 19.8737
# Epoch[1/15], Step [340/469], Reconst Loss: 115.5797, KL Div: 19.2840
# Epoch[1/15], Step [350/469], Reconst Loss: 115.8150, KL Div: 19.7161
# Epoch[1/15], Step [360/469], Reconst Loss: 116.3193, KL Div: 18.3045
# Epoch[1/15], Step [370/469], Reconst Loss: 111.6219, KL Div: 18.5504
# Epoch[1/15], Step [380/469], Reconst Loss: 112.5886, KL Div: 20.1466
# Epoch[1/15], Step [390/469], Reconst Loss: 115.3284, KL Div: 19.3554
# Epoch[1/15], Step [400/469], Reconst Loss: 113.3587, KL Div: 21.5544
# Epoch[1/15], Step [410/469], Reconst Loss: 110.4530, KL Div: 18.8027
# Epoch[1/15], Step [420/469], Reconst Loss: 107.9243, KL Div: 20.4922
# Epoch[1/15], Step [430/469], Reconst Loss: 109.3160, KL Div: 20.4245
# Epoch[1/15], Step [440/469], Reconst Loss: 114.4811, KL Div: 20.0350
# Epoch[1/15], Step [450/469], Reconst Loss: 112.6926, KL Div: 19.2896
# Epoch[1/15], Step [460/469], Reconst Loss: 103.8599, KL Div: 20.7371
# Epoch[2/15], Step [10/469], Reconst Loss: 104.2876, KL Div: 20.1543
# Epoch[2/15], Step [20/469], Reconst Loss: 105.2941, KL Div: 19.6045
# Epoch[2/15], Step [30/469], Reconst Loss: 106.1790, KL Div: 20.1217
# Epoch[2/15], Step [40/469], Reconst Loss: 110.3767, KL Div: 20.3504
# Epoch[2/15], Step [50/469], Reconst Loss: 103.3995, KL Div: 21.0638
# Epoch[2/15], Step [60/469], Reconst Loss: 105.6910, KL Div: 20.7341
# Epoch[2/15], Step [70/469], Reconst Loss: 106.2222, KL Div: 20.9418
# Epoch[2/15], Step [80/469], Reconst Loss: 104.4599, KL Div: 20.6944
# Epoch[2/15], Step [90/469], Reconst Loss: 100.4815, KL Div: 20.1705
# Epoch[2/15], Step [100/469], Reconst Loss: 104.1674, KL Div: 20.7591
# Epoch[2/15], Step [110/469], Reconst Loss: 105.4324, KL Div: 21.3258
# Epoch[2/15], Step [120/469], Reconst Loss: 104.4313, KL Div: 19.5231
# Epoch[2/15], Step [130/469], Reconst Loss: 98.6019, KL Div: 22.3089
# Epoch[2/15], Step [140/469], Reconst Loss: 103.2808, KL Div: 21.6941
# Epoch[2/15], Step [150/469], Reconst Loss: 105.9559, KL Div: 21.1372
# Epoch[2/15], Step [160/469], Reconst Loss: 102.5998, KL Div: 21.8070
# Epoch[2/15], Step [170/469], Reconst Loss: 100.7418, KL Div: 21.3861
# Epoch[2/15], Step [180/469], Reconst Loss: 97.7011, KL Div: 21.6614
# Epoch[2/15], Step [190/469], Reconst Loss: 105.4462, KL Div: 21.8609
# Epoch[2/15], Step [200/469], Reconst Loss: 101.6171, KL Div: 22.2241
# Epoch[2/15], Step [210/469], Reconst Loss: 106.2273, KL Div: 22.0279
# Epoch[2/15], Step [220/469], Reconst Loss: 101.4638, KL Div: 21.9111
# Epoch[2/15], Step [230/469], Reconst Loss: 97.5179, KL Div: 21.3948
# Epoch[2/15], Step [240/469], Reconst Loss: 107.4634, KL Div: 22.8924
# Epoch[2/15], Step [250/469], Reconst Loss: 95.4635, KL Div: 20.8441
# Epoch[2/15], Step [260/469], Reconst Loss: 102.7999, KL Div: 22.6706
# Epoch[2/15], Step [270/469], Reconst Loss: 98.9445, KL Div: 22.4129
# Epoch[2/15], Step [280/469], Reconst Loss: 95.8070, KL Div: 21.6843
# Epoch[2/15], Step [290/469], Reconst Loss: 99.4420, KL Div: 22.5069
# Epoch[5/15], Step [370/469], Reconst Loss: 83.0448, KL Div: 25.2053
# Epoch[5/15], Step [380/469], Reconst Loss: 80.5290, KL Div: 24.2948
# Epoch[5/15], Step [390/469], Reconst Loss: 83.0091, KL Div: 25.4469
# Epoch[5/15], Step [400/469], Reconst Loss: 83.7449, KL Div: 24.7534
# Epoch[5/15], Step [410/469], Reconst Loss: 88.1049, KL Div: 25.1467
# Epoch[5/15], Step [420/469], Reconst Loss: 80.6567, KL Div: 24.9915
# Epoch[5/15], Step [430/469], Reconst Loss: 85.2536, KL Div: 24.7370
# Epoch[5/15], Step [440/469], Reconst Loss: 83.4140, KL Div: 24.5840
# Epoch[5/15], Step [450/469], Reconst Loss: 85.9797, KL Div: 25.0025
# Epoch[5/15], Step [460/469], Reconst Loss: 81.2427, KL Div: 25.3051
# Epoch[6/15], Step [10/469], Reconst Loss: 80.9725, KL Div: 25.2102
# Epoch[6/15], Step [20/469], Reconst Loss: 82.4509, KL Div: 24.5899
# Epoch[6/15], Step [30/469], Reconst Loss: 82.7165, KL Div: 24.7090
# Epoch[6/15], Step [40/469], Reconst Loss: 87.3175, KL Div: 25.0167
# Epoch[6/15], Step [50/469], Reconst Loss: 81.6044, KL Div: 24.6172
# Epoch[6/15], Step [60/469], Reconst Loss: 81.4720, KL Div: 23.8462
# Epoch[6/15], Step [70/469], Reconst Loss: 82.4803, KL Div: 24.2643
# Epoch[6/15], Step [80/469], Reconst Loss: 82.8480, KL Div: 24.9594
# Epoch[6/15], Step [90/469], Reconst Loss: 82.5232, KL Div: 24.8561
# Epoch[6/15], Step [100/469], Reconst Loss: 84.8562, KL Div: 25.1225
# Epoch[6/15], Step [110/469], Reconst Loss: 81.1468, KL Div: 24.6540
# Epoch[6/15], Step [120/469], Reconst Loss: 85.8183, KL Div: 24.8047
# Epoch[6/15], Step [130/469], Reconst Loss: 83.8399, KL Div: 24.8320
# Epoch[6/15], Step [140/469], Reconst Loss: 83.9160, KL Div: 25.6525
# Epoch[6/15], Step [150/469], Reconst Loss: 86.0815, KL Div: 24.5279
# Epoch[6/15], Step [160/469], Reconst Loss: 82.2286, KL Div: 24.7861
# Epoch[6/15], Step [170/469], Reconst Loss: 83.5527, KL Div: 25.3009
# Epoch[6/15], Step [180/469], Reconst Loss: 81.4188, KL Div: 24.4513
# Epoch[6/15], Step [190/469], Reconst Loss: 84.8069, KL Div: 25.4091
# Epoch[6/15], Step [200/469], Reconst Loss: 81.2679, KL Div: 24.4109
# Epoch[6/15], Step [210/469], Reconst Loss: 84.3026, KL Div: 24.2186
# Epoch[6/15], Step [220/469], Reconst Loss: 86.0138, KL Div: 25.6304
# Epoch[6/15], Step [230/469], Reconst Loss: 80.9348, KL Div: 25.0430
# Epoch[6/15], Step [240/469], Reconst Loss: 81.6819, KL Div: 25.1053
# Epoch[6/15], Step [250/469], Reconst Loss: 84.2646, KL Div: 24.8253
# Epoch[6/15], Step [260/469], Reconst Loss: 82.7262, KL Div: 24.8103
# Epoch[6/15], Step [270/469], Reconst Loss: 84.1046, KL Div: 25.0344
# Epoch[8/15], Step [80/469], Reconst Loss: 78.3771, KL Div: 25.8761
# Epoch[8/15], Step [90/469], Reconst Loss: 83.8649, KL Div: 24.0425
# Epoch[8/15], Step [100/469], Reconst Loss: 85.5435, KL Div: 26.5239
# Epoch[8/15], Step [110/469], Reconst Loss: 79.1739, KL Div: 24.6075
# Epoch[8/15], Step [120/469], Reconst Loss: 83.4723, KL Div: 24.5553
# Epoch[8/15], Step [130/469], Reconst Loss: 84.4489, KL Div: 25.6809
# Epoch[8/15], Step [140/469], Reconst Loss: 83.2080, KL Div: 26.0422
# Epoch[8/15], Step [150/469], Reconst Loss: 81.9153, KL Div: 25.4523
# Epoch[8/15], Step [160/469], Reconst Loss: 84.2508, KL Div: 25.1872
# Epoch[8/15], Step [170/469], Reconst Loss: 79.8022, KL Div: 24.5890
# Epoch[8/15], Step [180/469], Reconst Loss: 80.0198, KL Div: 25.6653
# Epoch[8/15], Step [190/469], Reconst Loss: 84.0267, KL Div: 24.3643
# Epoch[8/15], Step [200/469], Reconst Loss: 83.8782, KL Div: 25.7262
# Epoch[8/15], Step [210/469], Reconst Loss: 80.6622, KL Div: 24.6892
# Epoch[8/15], Step [220/469], Reconst Loss: 82.8716, KL Div: 25.3649
# Epoch[8/15], Step [230/469], Reconst Loss: 85.1480, KL Div: 24.8373
# Epoch[8/15], Step [240/469], Reconst Loss: 79.6834, KL Div: 24.8176
# Epoch[8/15], Step [250/469], Reconst Loss: 79.2961, KL Div: 24.5574
# Epoch[8/15], Step [260/469], Reconst Loss: 80.7849, KL Div: 24.6682
# Epoch[8/15], Step [270/469], Reconst Loss: 84.8344, KL Div: 24.7221
# Epoch[8/15], Step [280/469], Reconst Loss: 78.9325, KL Div: 24.7007
# Epoch[8/15], Step [290/469], Reconst Loss: 80.8523, KL Div: 24.7857
# Epoch[8/15], Step [300/469], Reconst Loss: 84.7751, KL Div: 25.5286
# Epoch[8/15], Step [310/469], Reconst Loss: 79.9342, KL Div: 24.8284
# Epoch[8/15], Step [320/469], Reconst Loss: 82.5556, KL Div: 25.3070
# Epoch[8/15], Step [330/469], Reconst Loss: 81.6850, KL Div: 25.5277
# Epoch[8/15], Step [340/469], Reconst Loss: 79.8980, KL Div: 24.6944
# Epoch[8/15], Step [350/469], Reconst Loss: 83.1029, KL Div: 24.5707
# Epoch[8/15], Step [360/469], Reconst Loss: 77.6910, KL Div: 24.9356
# Epoch[8/15], Step [370/469], Reconst Loss: 79.2131, KL Div: 25.2321
# Epoch[8/15], Step [380/469], Reconst Loss: 83.4186, KL Div: 24.5494
# Epoch[8/15], Step [390/469], Reconst Loss: 82.1589, KL Div: 25.6672
# Epoch[8/15], Step [400/469], Reconst Loss: 82.7227, KL Div: 25.1356
# Epoch[8/15], Step [410/469], Reconst Loss: 82.2309, KL Div: 24.8934
# Epoch[8/15], Step [420/469], Reconst Loss: 81.1572, KL Div: 25.8294
# Epoch[8/15], Step [430/469], Reconst Loss: 80.3080, KL Div: 25.2614
# Epoch[9/15], Step [350/469], Reconst Loss: 79.9504, KL Div: 24.9050
# Epoch[9/15], Step [360/469], Reconst Loss: 81.5725, KL Div: 25.5345
# Epoch[9/15], Step [370/469], Reconst Loss: 79.9118, KL Div: 24.4613
# Epoch[9/15], Step [380/469], Reconst Loss: 80.5545, KL Div: 24.8115
# Epoch[9/15], Step [390/469], Reconst Loss: 78.8818, KL Div: 24.8663
# Epoch[9/15], Step [400/469], Reconst Loss: 81.2071, KL Div: 25.0856
# Epoch[9/15], Step [410/469], Reconst Loss: 80.8024, KL Div: 25.4717
# Epoch[9/15], Step [420/469], Reconst Loss: 78.5018, KL Div: 24.7360
# Epoch[9/15], Step [430/469], Reconst Loss: 82.1106, KL Div: 24.7815
# Epoch[9/15], Step [440/469], Reconst Loss: 80.7472, KL Div: 24.3615
# Epoch[9/15], Step [450/469], Reconst Loss: 82.4124, KL Div: 25.1630
# Epoch[9/15], Step [460/469], Reconst Loss: 80.5533, KL Div: 24.9381
# Epoch[10/15], Step [10/469], Reconst Loss: 78.9289, KL Div: 25.3502
# Epoch[10/15], Step [20/469], Reconst Loss: 77.4179, KL Div: 24.2294
# Epoch[10/15], Step [30/469], Reconst Loss: 84.6560, KL Div: 25.6580
# Epoch[10/15], Step [40/469], Reconst Loss: 81.2854, KL Div: 25.3267
# Epoch[10/15], Step [50/469], Reconst Loss: 78.4264, KL Div: 24.9563
# Epoch[10/15], Step [60/469], Reconst Loss: 80.0790, KL Div: 24.4899
# Epoch[10/15], Step [70/469], Reconst Loss: 82.8665, KL Div: 24.9920
# Epoch[10/15], Step [80/469], Reconst Loss: 83.4795, KL Div: 26.0124
# Epoch[10/15], Step [90/469], Reconst Loss: 80.0011, KL Div: 25.0773
# Epoch[10/15], Step [100/469], Reconst Loss: 81.1377, KL Div: 25.1612
# Epoch[10/15], Step [110/469], Reconst Loss: 82.9690, KL Div: 25.4202
# Epoch[10/15], Step [120/469], Reconst Loss: 80.0189, KL Div: 25.0060
# Epoch[10/15], Step [130/469], Reconst Loss: 83.1849, KL Div: 25.6720
# Epoch[10/15], Step [140/469], Reconst Loss: 79.9972, KL Div: 24.9300
# Epoch[10/15], Step [150/469], Reconst Loss: 82.5128, KL Div: 25.3209
# Epoch[10/15], Step [160/469], Reconst Loss: 80.3005, KL Div: 24.9804
# Epoch[10/15], Step [170/469], Reconst Loss: 85.9791, KL Div: 26.0890
# Epoch[10/15], Step [180/469], Reconst Loss: 81.0588, KL Div: 25.3630
# Epoch[10/15], Step [190/469], Reconst Loss: 76.4607, KL Div: 24.5356
# Epoch[10/15], Step [200/469], Reconst Loss: 84.9498, KL Div: 25.0816
# Epoch[10/15], Step [210/469], Reconst Loss: 79.6568, KL Div: 25.2725
# Epoch[10/15], Step [220/469], Reconst Loss: 77.5760, KL Div: 25.6091
# Epoch[10/15], Step [230/469], Reconst Loss: 81.2593, KL Div: 24.9970
# Epoch[10/15], Step [240/469], Reconst Loss: 83.3470, KL Div: 25.1573
# Epoch[10/15], Step [250/469], Reconst Loss: 82.4165, KL Div: 25.6965
# Epoch[10/15], Step [260/469], Reconst Loss: 80.5370, KL Div: 24.5765
# Epoch[10/15], Step [270/469], Reconst Loss: 74.8748, KL Div: 23.9478
# Epoch[10/15], Step [280/469], Reconst Loss: 82.3036, KL Div: 25.8043
# Epoch[10/15], Step [290/469], Reconst Loss: 81.2113, KL Div: 24.4333
# Epoch[10/15], Step [300/469], Reconst Loss: 83.0259, KL Div: 25.4906
# Epoch[10/15], Step [310/469], Reconst Loss: 79.3753, KL Div: 25.0117
# Epoch[10/15], Step [320/469], Reconst Loss: 78.5655, KL Div: 24.7006
# Epoch[10/15], Step [330/469], Reconst Loss: 81.2549, KL Div: 25.1718
# Epoch[10/15], Step [340/469], Reconst Loss: 81.2825, KL Div: 25.1652
# Epoch[10/15], Step [350/469], Reconst Loss: 80.1288, KL Div: 25.8267
# Epoch[10/15], Step [360/469], Reconst Loss: 76.4621, KL Div: 24.7126
# Epoch[10/15], Step [370/469], Reconst Loss: 81.7785, KL Div: 25.0774
# Epoch[10/15], Step [380/469], Reconst Loss: 78.2398, KL Div: 25.3361
# Epoch[10/15], Step [390/469], Reconst Loss: 81.6495, KL Div: 25.5894
# Epoch[10/15], Step [400/469], Reconst Loss: 83.6465, KL Div: 25.6282
# Epoch[10/15], Step [410/469], Reconst Loss: 78.4969, KL Div: 24.8985
# Epoch[10/15], Step [420/469], Reconst Loss: 79.6427, KL Div: 24.7427
# Epoch[10/15], Step [430/469], Reconst Loss: 82.0629, KL Div: 24.9737
# Epoch[10/15], Step [440/469], Reconst Loss: 81.1852, KL Div: 25.3949
# Epoch[10/15], Step [450/469], Reconst Loss: 76.8164, KL Div: 24.8585
# Epoch[10/15], Step [460/469], Reconst Loss: 80.3283, KL Div: 24.5906
# Epoch[11/15], Step [10/469], Reconst Loss: 82.7200, KL Div: 25.3784
# Epoch[11/15], Step [20/469], Reconst Loss: 78.4127, KL Div: 25.5686
# Epoch[11/15], Step [30/469], Reconst Loss: 78.5299, KL Div: 24.2194
# Epoch[11/15], Step [40/469], Reconst Loss: 79.5474, KL Div: 25.0732
# Epoch[11/15], Step [50/469], Reconst Loss: 80.4346, KL Div: 26.1105
# Epoch[11/15], Step [60/469], Reconst Loss: 80.9914, KL Div: 24.7844
# Epoch[11/15], Step [70/469], Reconst Loss: 81.2452, KL Div: 25.0411
# Epoch[11/15], Step [80/469], Reconst Loss: 81.9334, KL Div: 25.4121
# Epoch[11/15], Step [90/469], Reconst Loss: 78.7504, KL Div: 25.2024
# Epoch[11/15], Step [100/469], Reconst Loss: 82.7173, KL Div: 25.3020
# Epoch[11/15], Step [110/469], Reconst Loss: 76.7788, KL Div: 24.9910
# Epoch[11/15], Step [120/469], Reconst Loss: 82.7090, KL Div: 25.2960
# Epoch[11/15], Step [130/469], Reconst Loss: 79.8098, KL Div: 25.7784
# Epoch[11/15], Step [140/469], Reconst Loss: 81.0160, KL Div: 25.8064
# Epoch[12/15], Step [420/469], Reconst Loss: 83.0702, KL Div: 25.4211
# Epoch[12/15], Step [430/469], Reconst Loss: 80.3128, KL Div: 25.5243
# Epoch[12/15], Step [440/469], Reconst Loss: 80.7077, KL Div: 25.4178
# Epoch[12/15], Step [450/469], Reconst Loss: 80.4490, KL Div: 25.4883
# Epoch[12/15], Step [460/469], Reconst Loss: 79.6287, KL Div: 25.8254
# Epoch[13/15], Step [10/469], Reconst Loss: 79.1673, KL Div: 24.2917
# Epoch[13/15], Step [20/469], Reconst Loss: 80.4887, KL Div: 24.9065
# Epoch[13/15], Step [30/469], Reconst Loss: 78.3960, KL Div: 24.9402
# Epoch[13/15], Step [40/469], Reconst Loss: 79.1893, KL Div: 25.5978
# Epoch[13/15], Step [50/469], Reconst Loss: 80.6921, KL Div: 25.6523
# Epoch[13/15], Step [60/469], Reconst Loss: 81.8016, KL Div: 25.6997
# Epoch[13/15], Step [70/469], Reconst Loss: 79.7051, KL Div: 24.8518
# Epoch[13/15], Step [80/469], Reconst Loss: 79.8751, KL Div: 25.4754
# Epoch[13/15], Step [90/469], Reconst Loss: 78.5725, KL Div: 26.0606
# Epoch[13/15], Step [100/469], Reconst Loss: 80.2284, KL Div: 25.7638
# Epoch[13/15], Step [110/469], Reconst Loss: 79.4159, KL Div: 25.6562
# Epoch[13/15], Step [120/469], Reconst Loss: 81.6108, KL Div: 25.3134
# Epoch[13/15], Step [130/469], Reconst Loss: 81.5251, KL Div: 25.3419
# Epoch[13/15], Step [140/469], Reconst Loss: 77.3260, KL Div: 25.3323
# Epoch[13/15], Step [150/469], Reconst Loss: 81.4996, KL Div: 25.8241
# Epoch[13/15], Step [160/469], Reconst Loss: 78.1773, KL Div: 25.0613
# Epoch[13/15], Step [170/469], Reconst Loss: 81.7621, KL Div: 25.8606
# Epoch[13/15], Step [180/469], Reconst Loss: 77.4000, KL Div: 24.8750
# Epoch[13/15], Step [190/469], Reconst Loss: 77.0442, KL Div: 25.2264
# Epoch[13/15], Step [200/469], Reconst Loss: 76.0850, KL Div: 25.5616
# Epoch[13/15], Step [210/469], Reconst Loss: 80.4790, KL Div: 26.2901
# Epoch[13/15], Step [220/469], Reconst Loss: 80.0986, KL Div: 25.0711
# Epoch[13/15], Step [230/469], Reconst Loss: 83.1620, KL Div: 25.4132
# Epoch[13/15], Step [240/469], Reconst Loss: 83.1923, KL Div: 26.0925
# Epoch[13/15], Step [250/469], Reconst Loss: 84.9566, KL Div: 25.5456
# Epoch[13/15], Step [260/469], Reconst Loss: 79.5126, KL Div: 25.3570
# Epoch[13/15], Step [270/469], Reconst Loss: 78.0621, KL Div: 25.0832
# Epoch[13/15], Step [280/469], Reconst Loss: 83.1178, KL Div: 26.2864
# Epoch[13/15], Step [290/469], Reconst Loss: 82.0640, KL Div: 25.2164
# Epoch[13/15], Step [300/469], Reconst Loss: 78.8257, KL Div: 25.3949
# Epoch[13/15], Step [310/469], Reconst Loss: 79.1606, KL Div: 24.9727
# Epoch[15/15], Step [120/469], Reconst Loss: 80.8197, KL Div: 25.1695
# Epoch[15/15], Step [130/469], Reconst Loss: 75.5864, KL Div: 25.0266
# Epoch[15/15], Step [140/469], Reconst Loss: 79.8946, KL Div: 25.7615
# Epoch[15/15], Step [150/469], Reconst Loss: 78.2887, KL Div: 25.3764
# Epoch[15/15], Step [160/469], Reconst Loss: 81.1715, KL Div: 25.4784
# Epoch[15/15], Step [170/469], Reconst Loss: 80.7685, KL Div: 25.2840
# Epoch[15/15], Step [180/469], Reconst Loss: 78.7268, KL Div: 25.1712
# Epoch[15/15], Step [190/469], Reconst Loss: 76.6538, KL Div: 24.7422
# Epoch[15/15], Step [200/469], Reconst Loss: 82.8665, KL Div: 25.5079
# Epoch[15/15], Step [210/469], Reconst Loss: 76.9848, KL Div: 25.4981
# Epoch[15/15], Step [220/469], Reconst Loss: 79.9986, KL Div: 25.7053
# Epoch[15/15], Step [230/469], Reconst Loss: 83.0843, KL Div: 24.8535
# Epoch[15/15], Step [240/469], Reconst Loss: 76.2705, KL Div: 26.1750
# Epoch[15/15], Step [250/469], Reconst Loss: 78.0992, KL Div: 25.3558
# Epoch[15/15], Step [260/469], Reconst Loss: 78.9090, KL Div: 24.5878
# Epoch[15/15], Step [270/469], Reconst Loss: 76.7378, KL Div: 25.7608
# Epoch[15/15], Step [280/469], Reconst Loss: 79.3696, KL Div: 25.4140
# Epoch[15/15], Step [290/469], Reconst Loss: 82.5140, KL Div: 25.0739
# Epoch[15/15], Step [300/469], Reconst Loss: 81.5327, KL Div: 25.5304
# Epoch[15/15], Step [310/469], Reconst Loss: 79.8238, KL Div: 25.4303
# Epoch[15/15], Step [320/469], Reconst Loss: 79.2755, KL Div: 25.3055
# Epoch[15/15], Step [330/469], Reconst Loss: 76.4844, KL Div: 25.1044
# Epoch[15/15], Step [340/469], Reconst Loss: 78.3295, KL Div: 25.0247
# Epoch[15/15], Step [350/469], Reconst Loss: 82.6063, KL Div: 25.8126
# Epoch[15/15], Step [360/469], Reconst Loss: 82.3910, KL Div: 25.1571
# Epoch[15/15], Step [370/469], Reconst Loss: 82.9479, KL Div: 25.0455
# Epoch[15/15], Step [380/469], Reconst Loss: 80.9619, KL Div: 25.8988
# Epoch[15/15], Step [390/469], Reconst Loss: 83.0070, KL Div: 26.0141
# Epoch[15/15], Step [400/469], Reconst Loss: 79.2216, KL Div: 25.9181
# Epoch[15/15], Step [410/469], Reconst Loss: 79.8780, KL Div: 25.1378
# Epoch[15/15], Step [420/469], Reconst Loss: 79.1268, KL Div: 24.8703
# Epoch[15/15], Step [430/469], Reconst Loss: 78.0394, KL Div: 25.7179
# Epoch[15/15], Step [440/469], Reconst Loss: 87.4878, KL Div: 25.0053
# Epoch[15/15], Step [450/469], Reconst Loss: 76.9870, KL Div: 24.6491
# Epoch[15/15], Step [460/469], Reconst Loss: 81.4204, KL Div: 26.1478

# %% [markdown]
# Let see how our network reconstructs our last batch. We display pairs of original digits and reconstructed version.

# %%
mu, _ = model.encode(x) 
out = model.decode(mu)
x_concat = torch.cat([x.view(-1, 1, 28, 28), out.view(-1, 1, 28, 28)], dim=3)
out_grid = torchvision.utils.make_grid(x_concat).cpu().data
show(out_grid)

# %% [markdown]
# Let see now, how our network generates new samples.

# %%
with torch.no_grad():
        z = torch.randn(16, z_dim).to(device)
        out = model.decode(z).view(-1, 1, 28, 28)

out_grid = torchvision.utils.make_grid(out).cpu()
show(out_grid)

# %% [markdown]
# Not great, but we did not train our network for long... That being said, we have no control of the generated digits. In the rest of this jupyter, we explore ways to generates zeros, ones, twos and so on. As a by product, we show how our VAE will allow us to do clustering.
#
# The main idea is to build what we call a Gumbel VAE as described below.

# %% [markdown]
# # Gumbel VAE
#
# Implement a VAE where you add a categorical variable $c\in \{0,\dots 9\}$ so that your latent variable model is $p(c,z,x) = p(c)p(z)p_{\theta}(x|,c,z)$ and your variational posterior is $q_{\phi}(c|x)q_{\phi}(z|x)$ as described in this NIPS [paper](https://arxiv.org/abs/1804.00104). Make minimal modifications to previous architecture...
#
# The idea is that you incorporates a categorical variable in your latent space. You hope that this categorical variable will encode the class of the digit, so that your network can use it for a better reconstruction. Moreover, if things work as planed, you will then be able to generate digits conditionally to the class, i.e. you can choose the class thanks to the latent categorical variable $c$ and then generate digits from this class.
#
# As noticed above, in order to sample random variables while still being able to use backpropagation required us to use the reparameterization trick which is easy for Gaussian random variables. For categorical random variables, the reparameterization trick is explained in this [paper](https://arxiv.org/abs/1611.01144). This is implemented in pytorch thanks to [F.gumbel_softmax](https://pytorch.org/docs/stable/nn.html?highlight=gumbel_softmax#torch.nn.functional.gumbel_softmax)

# %%
n_classes = 10

class VAE_Gumbel(nn.Module):
    def __init__(self, image_size=784, h_dim=400, z_dim=20, n_classes = 10):
        super(VAE_Gumbel, self).__init__()
      
        # your code here
        self.fc1 = nn.Linear(image_size, h_dim)
        self.fc2 = nn.Linear(h_dim, z_dim)
        self.fc3 = nn.Linear(h_dim, z_dim)
        self.fc4 = nn.Linear(h_dim, n_classes)
        self.fc5 = nn.Linear(z_dim + n_classes, h_dim)
        self.fc6 = nn.Linear(h_dim, image_size)
        
        
    def encode(self, x):
        
        # your code here / use F.log_softmax
        h = F.relu(self.fc1(x))
        dig_class = F.log_softmax(self.fc4(h), dim=1)
        
        return self.fc2(h), self.fc3(h), dig_class
        
    
    def reparameterize(self, mu, log_var):
        std = torch.exp(log_var/2)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z, y_onehot):
        
        # your code here / use torch.cat 
        h = F.relu(self.fc5(torch.cat((z, y_onehot), dim=1)))
        return torch.sigmoid(self.fc6(h))
            
    def forward(self, x):
        
        # your code here / use F.gumbel_softmax
        mu, log_var, y_onehot = self.encode(x)
        z = self.reparameterize(mu, log_var)
        x_reconst = self.decode(z, F.gumbel_softmax(y_onehot))
        return x_reconst, mu, log_var, y_onehot
        

model_G = VAE_Gumbel().to(device)
optimizer = torch.optim.Adam(model_G.parameters(), lr=learning_rate)

# %% [markdown]
# You need to modify the loss to take into account the categorical random variable with an uniform prior on $\{0,\dots 9\}$, see Appendix A.2 in the NIPS [paper](https://arxiv.org/abs/1804.00104)

# %%
from torch.autograd import Variable
def train_G(model, data_loader=data_loader,num_epochs=num_epochs, beta = 1., verbose=True):
    nmi_scores = []
    model.train(True)
    for epoch in range(num_epochs):
        all_labels = []
        all_labels_est = []
        for i, (x, labels) in enumerate(data_loader):
            # Forward pass
            x = x.to(device).view(-1, image_size)
            
            # your code here
            x_reconst, mu, log_var, y_onehot = model(x)
            reconst_loss = F.binary_cross_entropy(x_reconst, x, reduction='sum')
            
            # your code here
            # g = Variable(torch.log(torch.Tensor([1.0/n_classes])).cuda())
            # kl_div = torch.sum(y_onehot*(torch.log(y_onehot+1e-20) - g),dim=-1).mean()
            ## This method does not work on my laptop due to CUDA problem
            ## According to the discussion in Forum, we calc onehot of the digit labels
            dig_onehot = torch.FloatTensor(labels.size(0), 10)
            dig_onehot.zero_()
            dig_onehot.scatter_(1, labels.view(-1,1), 1)
            kl_div1 = - 0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
            kl_div2 = - torch.sum(y_onehot * dig_onehot.to(device))

            # Backprop and optimize
            loss = reconst_loss + beta*(kl_div1 + kl_div2) # your code here
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if verbose:
                if (i+1) % 10 == 0:
                    print ("Epoch[{}/{}], Step [{}/{}], Reconst Loss: {:.4f}, KL Div: {:.4f}, Entropy: {:.4f}" 
                           .format(epoch+1, num_epochs, i+1, len(data_loader), reconst_loss.item()/batch_size,
                                   kl_div1.item()/batch_size, kl_div2.item()/batch_size))

# %%
train_G(model_G,num_epochs=10,verbose=True)
# Out:
# Epoch[1/10], Step [10/469], Reconst Loss: 296.2823, KL Div: 26.9708, Entropy: 2.3702
# Epoch[1/10], Step [20/469], Reconst Loss: 230.6251, KL Div: 9.0571, Entropy: 2.1896
# Epoch[1/10], Step [30/469], Reconst Loss: 215.2428, KL Div: 9.4855, Entropy: 2.0707
# Epoch[1/10], Step [40/469], Reconst Loss: 202.8672, KL Div: 5.1698, Entropy: 1.9626
# Epoch[1/10], Step [50/469], Reconst Loss: 215.5986, KL Div: 5.1636, Entropy: 1.9240
# Epoch[1/10], Step [60/469], Reconst Loss: 204.4977, KL Div: 6.3763, Entropy: 1.6457
# Epoch[1/10], Step [70/469], Reconst Loss: 196.0978, KL Div: 7.9319, Entropy: 1.4997
# Epoch[1/10], Step [80/469], Reconst Loss: 184.5514, KL Div: 8.0477, Entropy: 1.3077
# Epoch[1/10], Step [90/469], Reconst Loss: 176.9706, KL Div: 10.0387, Entropy: 1.1447
# Epoch[1/10], Step [100/469], Reconst Loss: 168.1660, KL Div: 10.7265, Entropy: 0.9937
# Epoch[1/10], Step [110/469], Reconst Loss: 164.0460, KL Div: 12.2768, Entropy: 0.9536
# Epoch[1/10], Step [120/469], Reconst Loss: 164.5760, KL Div: 12.0204, Entropy: 0.7495
# Epoch[1/10], Step [130/469], Reconst Loss: 158.6619, KL Div: 12.8124, Entropy: 0.7673
# Epoch[1/10], Step [140/469], Reconst Loss: 146.5830, KL Div: 13.3368, Entropy: 0.6675
# Epoch[1/10], Step [150/469], Reconst Loss: 152.6699, KL Div: 13.4914, Entropy: 0.7538
# Epoch[1/10], Step [160/469], Reconst Loss: 153.2467, KL Div: 13.6511, Entropy: 0.7367
# Epoch[1/10], Step [170/469], Reconst Loss: 138.8043, KL Div: 14.6394, Entropy: 0.6547
# Epoch[1/10], Step [180/469], Reconst Loss: 141.4627, KL Div: 14.2566, Entropy: 0.5487
# Epoch[1/10], Step [190/469], Reconst Loss: 142.3547, KL Div: 14.3993, Entropy: 0.6387
# Epoch[1/10], Step [200/469], Reconst Loss: 138.7329, KL Div: 15.2035, Entropy: 0.6223
# Epoch[1/10], Step [210/469], Reconst Loss: 132.9936, KL Div: 15.5611, Entropy: 0.5040
# Epoch[1/10], Step [220/469], Reconst Loss: 133.5860, KL Div: 15.3861, Entropy: 0.4435
# Epoch[1/10], Step [230/469], Reconst Loss: 132.6698, KL Div: 14.9993, Entropy: 0.4950
# Epoch[1/10], Step [240/469], Reconst Loss: 134.9294, KL Div: 16.2707, Entropy: 0.4856
# Epoch[1/10], Step [250/469], Reconst Loss: 131.6387, KL Div: 15.4324, Entropy: 0.6899
# Epoch[1/10], Step [260/469], Reconst Loss: 129.9470, KL Div: 15.7686, Entropy: 0.4850
# Epoch[1/10], Step [270/469], Reconst Loss: 124.8151, KL Div: 15.8309, Entropy: 0.5558
# Epoch[1/10], Step [280/469], Reconst Loss: 130.6160, KL Div: 17.3902, Entropy: 0.3639
# Epoch[1/10], Step [290/469], Reconst Loss: 124.6222, KL Div: 16.8112, Entropy: 0.4973
# Epoch[1/10], Step [300/469], Reconst Loss: 121.6319, KL Div: 17.1328, Entropy: 0.4955
# Epoch[1/10], Step [310/469], Reconst Loss: 121.0947, KL Div: 17.7582, Entropy: 0.4564
# Epoch[1/10], Step [320/469], Reconst Loss: 118.8820, KL Div: 17.1162, Entropy: 0.3570
# Epoch[1/10], Step [330/469], Reconst Loss: 115.2903, KL Div: 19.0835, Entropy: 0.4189
# Epoch[1/10], Step [340/469], Reconst Loss: 114.3983, KL Div: 17.5927, Entropy: 0.3607
# Epoch[1/10], Step [350/469], Reconst Loss: 114.7305, KL Div: 19.1516, Entropy: 0.3986
# Epoch[1/10], Step [360/469], Reconst Loss: 117.7392, KL Div: 16.9727, Entropy: 0.3861
# Epoch[1/10], Step [370/469], Reconst Loss: 114.1748, KL Div: 18.6129, Entropy: 0.3731
# Epoch[1/10], Step [380/469], Reconst Loss: 119.2827, KL Div: 18.1399, Entropy: 0.4155
# Epoch[1/10], Step [390/469], Reconst Loss: 122.5773, KL Div: 18.4764, Entropy: 0.4480
# Epoch[1/10], Step [400/469], Reconst Loss: 114.9304, KL Div: 18.1599, Entropy: 0.3959
# Epoch[1/10], Step [410/469], Reconst Loss: 110.6856, KL Div: 18.4483, Entropy: 0.5474
# Epoch[1/10], Step [420/469], Reconst Loss: 115.2063, KL Div: 18.9741, Entropy: 0.4377
# Epoch[1/10], Step [430/469], Reconst Loss: 107.6844, KL Div: 17.4803, Entropy: 0.4604
# Epoch[1/10], Step [440/469], Reconst Loss: 108.4707, KL Div: 19.3774, Entropy: 0.2502
# Epoch[1/10], Step [450/469], Reconst Loss: 114.1190, KL Div: 19.0991, Entropy: 0.5703
# Epoch[1/10], Step [460/469], Reconst Loss: 107.1454, KL Div: 19.3143, Entropy: 0.4688
# Epoch[2/10], Step [10/469], Reconst Loss: 105.0250, KL Div: 19.3899, Entropy: 0.3118
# Epoch[2/10], Step [20/469], Reconst Loss: 107.2570, KL Div: 17.7557, Entropy: 0.3576
# Epoch[2/10], Step [30/469], Reconst Loss: 106.4591, KL Div: 20.3945, Entropy: 0.4320
# Epoch[2/10], Step [40/469], Reconst Loss: 105.6112, KL Div: 19.7780, Entropy: 0.3649
# Epoch[2/10], Step [50/469], Reconst Loss: 109.0068, KL Div: 19.5812, Entropy: 0.3273
# Epoch[2/10], Step [60/469], Reconst Loss: 111.3593, KL Div: 19.8564, Entropy: 0.4815
# Epoch[2/10], Step [70/469], Reconst Loss: 103.7185, KL Div: 19.1450, Entropy: 0.3690
# Epoch[2/10], Step [80/469], Reconst Loss: 100.9337, KL Div: 20.5721, Entropy: 0.4073
# Epoch[2/10], Step [90/469], Reconst Loss: 101.6956, KL Div: 19.7636, Entropy: 0.3286
# Epoch[2/10], Step [100/469], Reconst Loss: 101.6055, KL Div: 19.8370, Entropy: 0.2517
# Epoch[2/10], Step [110/469], Reconst Loss: 100.8500, KL Div: 20.2199, Entropy: 0.4378
# Epoch[2/10], Step [120/469], Reconst Loss: 106.0400, KL Div: 20.8275, Entropy: 0.3910
# Epoch[2/10], Step [130/469], Reconst Loss: 99.4596, KL Div: 19.6695, Entropy: 0.2813
# Epoch[2/10], Step [140/469], Reconst Loss: 102.5918, KL Div: 20.4516, Entropy: 0.4144
# Epoch[2/10], Step [150/469], Reconst Loss: 103.5192, KL Div: 20.1080, Entropy: 0.4527
# Epoch[2/10], Step [160/469], Reconst Loss: 102.5205, KL Div: 20.3058, Entropy: 0.3654
# Epoch[2/10], Step [170/469], Reconst Loss: 103.4345, KL Div: 19.1195, Entropy: 0.3648
# Epoch[2/10], Step [180/469], Reconst Loss: 102.7167, KL Div: 20.1870, Entropy: 0.3319
# Epoch[2/10], Step [190/469], Reconst Loss: 104.6699, KL Div: 20.6083, Entropy: 0.4101
# Epoch[2/10], Step [200/469], Reconst Loss: 101.0210, KL Div: 20.6441, Entropy: 0.2022
# Epoch[2/10], Step [210/469], Reconst Loss: 96.1780, KL Div: 20.5609, Entropy: 0.2939
# Epoch[2/10], Step [220/469], Reconst Loss: 101.1697, KL Div: 20.1852, Entropy: 0.2405
# Epoch[2/10], Step [230/469], Reconst Loss: 104.2057, KL Div: 21.3573, Entropy: 0.2704
# Epoch[2/10], Step [240/469], Reconst Loss: 98.8891, KL Div: 20.2395, Entropy: 0.3792
# Epoch[2/10], Step [250/469], Reconst Loss: 99.6347, KL Div: 20.3260, Entropy: 0.2755
# Epoch[2/10], Step [260/469], Reconst Loss: 105.4546, KL Div: 20.3691, Entropy: 0.4047
# Epoch[2/10], Step [270/469], Reconst Loss: 96.5819, KL Div: 20.6203, Entropy: 0.3220
# Epoch[2/10], Step [280/469], Reconst Loss: 97.3637, KL Div: 21.2813, Entropy: 0.4743
# Epoch[2/10], Step [290/469], Reconst Loss: 91.2496, KL Div: 19.9132, Entropy: 0.3440
# Epoch[2/10], Step [300/469], Reconst Loss: 101.6095, KL Div: 21.1183, Entropy: 0.3731
# Epoch[2/10], Step [310/469], Reconst Loss: 96.0715, KL Div: 21.2439, Entropy: 0.2294
# Epoch[2/10], Step [320/469], Reconst Loss: 101.8668, KL Div: 21.6223, Entropy: 0.5015
# Epoch[2/10], Step [330/469], Reconst Loss: 102.0011, KL Div: 20.7233, Entropy: 0.4451
# Epoch[2/10], Step [340/469], Reconst Loss: 93.5034, KL Div: 21.3115, Entropy: 0.3177
# Epoch[2/10], Step [350/469], Reconst Loss: 96.6030, KL Div: 20.5291, Entropy: 0.3190
# Epoch[2/10], Step [360/469], Reconst Loss: 95.3976, KL Div: 21.4146, Entropy: 0.3714
# Epoch[2/10], Step [370/469], Reconst Loss: 92.5223, KL Div: 20.3381, Entropy: 0.3118
# Epoch[2/10], Step [380/469], Reconst Loss: 97.5076, KL Div: 21.4222, Entropy: 0.3403
# Epoch[2/10], Step [390/469], Reconst Loss: 95.1614, KL Div: 20.4461, Entropy: 0.3730
# Epoch[2/10], Step [400/469], Reconst Loss: 95.4634, KL Div: 21.2340, Entropy: 0.4647
# Epoch[2/10], Step [410/469], Reconst Loss: 92.4748, KL Div: 20.7196, Entropy: 0.3513
# Epoch[2/10], Step [420/469], Reconst Loss: 95.7992, KL Div: 21.8625, Entropy: 0.2952
# Epoch[2/10], Step [430/469], Reconst Loss: 97.0887, KL Div: 20.9265, Entropy: 0.4491
# Epoch[2/10], Step [440/469], Reconst Loss: 91.7469, KL Div: 21.1105, Entropy: 0.1666
# Epoch[2/10], Step [450/469], Reconst Loss: 92.4763, KL Div: 21.0753, Entropy: 0.3387
# Epoch[2/10], Step [460/469], Reconst Loss: 94.1164, KL Div: 21.4247, Entropy: 0.2952
# Epoch[3/10], Step [10/469], Reconst Loss: 96.4088, KL Div: 21.0977, Entropy: 0.4205
# Epoch[3/10], Step [20/469], Reconst Loss: 93.5279, KL Div: 22.1589, Entropy: 0.2408
# Epoch[3/10], Step [30/469], Reconst Loss: 88.8771, KL Div: 21.0330, Entropy: 0.2957
# Epoch[3/10], Step [40/469], Reconst Loss: 90.2778, KL Div: 21.5101, Entropy: 0.2454
# Epoch[3/10], Step [50/469], Reconst Loss: 91.7014, KL Div: 22.4638, Entropy: 0.3212
# Epoch[3/10], Step [60/469], Reconst Loss: 94.9937, KL Div: 21.9541, Entropy: 0.2551
# Epoch[3/10], Step [70/469], Reconst Loss: 94.6470, KL Div: 22.0258, Entropy: 0.2739
# Epoch[3/10], Step [80/469], Reconst Loss: 92.2622, KL Div: 21.1118, Entropy: 0.3429
# Epoch[3/10], Step [90/469], Reconst Loss: 94.8667, KL Div: 21.6585, Entropy: 0.2039
# Epoch[3/10], Step [100/469], Reconst Loss: 92.2311, KL Div: 21.0198, Entropy: 0.3126
# Epoch[3/10], Step [110/469], Reconst Loss: 91.7364, KL Div: 22.1880, Entropy: 0.3294
# Epoch[3/10], Step [120/469], Reconst Loss: 91.4570, KL Div: 20.8521, Entropy: 0.3450
# Epoch[3/10], Step [130/469], Reconst Loss: 91.4989, KL Div: 21.3290, Entropy: 0.3617
# Epoch[3/10], Step [140/469], Reconst Loss: 96.8599, KL Div: 22.1483, Entropy: 0.3372
# Epoch[3/10], Step [150/469], Reconst Loss: 93.3064, KL Div: 21.8303, Entropy: 0.4054
# Epoch[3/10], Step [160/469], Reconst Loss: 93.6147, KL Div: 21.4950, Entropy: 0.2609
# Epoch[3/10], Step [170/469], Reconst Loss: 97.5106, KL Div: 22.1790, Entropy: 0.3598
# Epoch[3/10], Step [180/469], Reconst Loss: 92.4322, KL Div: 22.0332, Entropy: 0.3188
# Epoch[3/10], Step [190/469], Reconst Loss: 92.3291, KL Div: 21.9031, Entropy: 0.4592
# Epoch[3/10], Step [200/469], Reconst Loss: 90.9677, KL Div: 21.8001, Entropy: 0.2838
# Epoch[3/10], Step [210/469], Reconst Loss: 88.3379, KL Div: 21.4005, Entropy: 0.3526
# Epoch[3/10], Step [220/469], Reconst Loss: 94.8593, KL Div: 22.8672, Entropy: 0.3557
# Epoch[3/10], Step [230/469], Reconst Loss: 89.3479, KL Div: 21.7379, Entropy: 0.3201
# Epoch[3/10], Step [240/469], Reconst Loss: 90.3718, KL Div: 22.1874, Entropy: 0.2794
# Epoch[3/10], Step [250/469], Reconst Loss: 90.5571, KL Div: 21.6874, Entropy: 0.3149
# Epoch[3/10], Step [260/469], Reconst Loss: 83.9586, KL Div: 21.6586, Entropy: 0.2411
# Epoch[3/10], Step [270/469], Reconst Loss: 90.2857, KL Div: 21.9569, Entropy: 0.2969
# Epoch[3/10], Step [280/469], Reconst Loss: 89.8043, KL Div: 21.9739, Entropy: 0.3773
# Epoch[3/10], Step [290/469], Reconst Loss: 95.1882, KL Div: 23.1415, Entropy: 0.3133
# Epoch[3/10], Step [300/469], Reconst Loss: 93.9787, KL Div: 21.6709, Entropy: 0.4230
# Epoch[3/10], Step [310/469], Reconst Loss: 88.8457, KL Div: 21.8130, Entropy: 0.3821
# Epoch[3/10], Step [320/469], Reconst Loss: 88.3645, KL Div: 21.9539, Entropy: 0.2606
# Epoch[3/10], Step [330/469], Reconst Loss: 88.2227, KL Div: 21.8038, Entropy: 0.1895
# Epoch[3/10], Step [340/469], Reconst Loss: 88.7771, KL Div: 23.0076, Entropy: 0.2108
# Epoch[3/10], Step [350/469], Reconst Loss: 93.6844, KL Div: 22.5065, Entropy: 0.3447
# Epoch[3/10], Step [360/469], Reconst Loss: 89.6940, KL Div: 22.4869, Entropy: 0.3293
# Epoch[3/10], Step [370/469], Reconst Loss: 91.3602, KL Div: 21.7905, Entropy: 0.1465
# Epoch[3/10], Step [380/469], Reconst Loss: 88.3394, KL Div: 22.3262, Entropy: 0.3159
# Epoch[3/10], Step [390/469], Reconst Loss: 92.3417, KL Div: 22.2562, Entropy: 0.2850
# Epoch[3/10], Step [400/469], Reconst Loss: 87.9623, KL Div: 21.9853, Entropy: 0.3577
# Epoch[3/10], Step [410/469], Reconst Loss: 88.1484, KL Div: 22.1078, Entropy: 0.2190
# Epoch[3/10], Step [420/469], Reconst Loss: 87.1791, KL Div: 22.8551, Entropy: 0.2532
# Epoch[3/10], Step [430/469], Reconst Loss: 88.3643, KL Div: 22.5413, Entropy: 0.3490
# Epoch[3/10], Step [440/469], Reconst Loss: 87.1720, KL Div: 22.4987, Entropy: 0.2733
# Epoch[3/10], Step [450/469], Reconst Loss: 88.0601, KL Div: 22.7778, Entropy: 0.2239
# Epoch[3/10], Step [460/469], Reconst Loss: 89.9427, KL Div: 22.5759, Entropy: 0.3172
# Epoch[4/10], Step [10/469], Reconst Loss: 87.2152, KL Div: 22.3415, Entropy: 0.2573
# Epoch[4/10], Step [20/469], Reconst Loss: 86.7169, KL Div: 21.7887, Entropy: 0.2771
# Epoch[4/10], Step [30/469], Reconst Loss: 88.0296, KL Div: 22.1439, Entropy: 0.2859
# Epoch[4/10], Step [40/469], Reconst Loss: 90.0494, KL Div: 23.4886, Entropy: 0.2605
# Epoch[4/10], Step [50/469], Reconst Loss: 84.0438, KL Div: 21.6819, Entropy: 0.3604
# Epoch[4/10], Step [60/469], Reconst Loss: 90.2896, KL Div: 22.2005, Entropy: 0.2242
# Epoch[4/10], Step [70/469], Reconst Loss: 87.8483, KL Div: 22.4967, Entropy: 0.2585
# Epoch[4/10], Step [80/469], Reconst Loss: 87.7673, KL Div: 22.2508, Entropy: 0.2234
# Epoch[4/10], Step [90/469], Reconst Loss: 89.1935, KL Div: 21.8610, Entropy: 0.2763
# Epoch[4/10], Step [100/469], Reconst Loss: 92.7538, KL Div: 22.7260, Entropy: 0.2670
# Epoch[4/10], Step [110/469], Reconst Loss: 88.9073, KL Div: 22.0428, Entropy: 0.2400
# Epoch[4/10], Step [120/469], Reconst Loss: 86.6999, KL Div: 22.5859, Entropy: 0.2701
# Epoch[4/10], Step [130/469], Reconst Loss: 93.4969, KL Div: 22.3495, Entropy: 0.3316
# Epoch[4/10], Step [140/469], Reconst Loss: 90.8152, KL Div: 23.3203, Entropy: 0.2000
# Epoch[4/10], Step [150/469], Reconst Loss: 87.3420, KL Div: 22.4443, Entropy: 0.2535
# Epoch[4/10], Step [160/469], Reconst Loss: 84.5289, KL Div: 22.1914, Entropy: 0.2812
# Epoch[4/10], Step [170/469], Reconst Loss: 86.1242, KL Div: 23.0773, Entropy: 0.1704
# Epoch[4/10], Step [180/469], Reconst Loss: 85.6423, KL Div: 22.0615, Entropy: 0.3831
# Epoch[4/10], Step [190/469], Reconst Loss: 89.3942, KL Div: 23.2360, Entropy: 0.2850
# Epoch[4/10], Step [200/469], Reconst Loss: 86.2019, KL Div: 22.0263, Entropy: 0.3506
# Epoch[4/10], Step [210/469], Reconst Loss: 83.8178, KL Div: 23.2974, Entropy: 0.2320
# Epoch[4/10], Step [220/469], Reconst Loss: 86.3226, KL Div: 21.8082, Entropy: 0.3929
# Epoch[4/10], Step [230/469], Reconst Loss: 85.7656, KL Div: 22.2708, Entropy: 0.2192
# Epoch[4/10], Step [240/469], Reconst Loss: 87.8304, KL Div: 22.2911, Entropy: 0.4692
# Epoch[4/10], Step [250/469], Reconst Loss: 88.2264, KL Div: 22.5884, Entropy: 0.1523
# Epoch[4/10], Step [260/469], Reconst Loss: 84.2241, KL Div: 22.4139, Entropy: 0.2000
# Epoch[4/10], Step [270/469], Reconst Loss: 87.2101, KL Div: 22.8843, Entropy: 0.3355
# Epoch[4/10], Step [280/469], Reconst Loss: 90.8983, KL Div: 22.8994, Entropy: 0.3896
# Epoch[4/10], Step [290/469], Reconst Loss: 85.0904, KL Div: 22.9306, Entropy: 0.3392
# Epoch[4/10], Step [300/469], Reconst Loss: 87.9118, KL Div: 22.5139, Entropy: 0.3480
# Epoch[4/10], Step [310/469], Reconst Loss: 90.2036, KL Div: 22.7778, Entropy: 0.3218
# Epoch[4/10], Step [320/469], Reconst Loss: 87.8452, KL Div: 22.8483, Entropy: 0.2593
# Epoch[4/10], Step [330/469], Reconst Loss: 87.6125, KL Div: 22.8277, Entropy: 0.3065
# Epoch[4/10], Step [340/469], Reconst Loss: 86.4212, KL Div: 22.4854, Entropy: 0.1025
# Epoch[4/10], Step [350/469], Reconst Loss: 86.1362, KL Div: 21.8549, Entropy: 0.1653
# Epoch[4/10], Step [360/469], Reconst Loss: 89.3910, KL Div: 22.4025, Entropy: 0.3540
# Epoch[4/10], Step [370/469], Reconst Loss: 90.3505, KL Div: 23.4734, Entropy: 0.2221
# Epoch[4/10], Step [380/469], Reconst Loss: 85.6824, KL Div: 21.9901, Entropy: 0.2350
# Epoch[4/10], Step [390/469], Reconst Loss: 86.4166, KL Div: 23.5800, Entropy: 0.4258
# Epoch[4/10], Step [400/469], Reconst Loss: 82.4902, KL Div: 22.3052, Entropy: 0.1761
# Epoch[4/10], Step [410/469], Reconst Loss: 86.2288, KL Div: 22.8618, Entropy: 0.3154
# Epoch[4/10], Step [420/469], Reconst Loss: 89.7250, KL Div: 22.7235, Entropy: 0.3065
# Epoch[4/10], Step [430/469], Reconst Loss: 86.4469, KL Div: 22.7331, Entropy: 0.2276
# Epoch[4/10], Step [440/469], Reconst Loss: 87.0153, KL Div: 22.3932, Entropy: 0.3401
# Epoch[4/10], Step [450/469], Reconst Loss: 82.7285, KL Div: 22.0131, Entropy: 0.2204
# Epoch[4/10], Step [460/469], Reconst Loss: 87.1277, KL Div: 22.5520, Entropy: 0.2016
# Epoch[5/10], Step [10/469], Reconst Loss: 85.0923, KL Div: 22.7361, Entropy: 0.2036
# Epoch[5/10], Step [20/469], Reconst Loss: 93.5269, KL Div: 23.0111, Entropy: 0.2899
# Epoch[5/10], Step [30/469], Reconst Loss: 91.5849, KL Div: 22.6815, Entropy: 0.3016
# Epoch[5/10], Step [40/469], Reconst Loss: 83.1542, KL Div: 22.4477, Entropy: 0.3613
# Epoch[5/10], Step [50/469], Reconst Loss: 85.3879, KL Div: 22.5771, Entropy: 0.1972
# Epoch[5/10], Step [60/469], Reconst Loss: 83.5240, KL Div: 22.2758, Entropy: 0.3229
# Epoch[5/10], Step [70/469], Reconst Loss: 84.6057, KL Div: 22.9935, Entropy: 0.2118
# Epoch[5/10], Step [80/469], Reconst Loss: 87.7708, KL Div: 22.6982, Entropy: 0.2628
# Epoch[5/10], Step [90/469], Reconst Loss: 85.8653, KL Div: 22.4478, Entropy: 0.1670
# Epoch[5/10], Step [100/469], Reconst Loss: 83.8720, KL Div: 22.2298, Entropy: 0.2004
# Epoch[5/10], Step [110/469], Reconst Loss: 86.8769, KL Div: 22.4324, Entropy: 0.2365
# Epoch[5/10], Step [120/469], Reconst Loss: 86.8679, KL Div: 21.7585, Entropy: 0.2139
# Epoch[5/10], Step [130/469], Reconst Loss: 84.6032, KL Div: 22.7179, Entropy: 0.1747
# Epoch[5/10], Step [140/469], Reconst Loss: 86.9164, KL Div: 21.7697, Entropy: 0.1993
# Epoch[5/10], Step [150/469], Reconst Loss: 86.6870, KL Div: 22.5892, Entropy: 0.3098
# Epoch[5/10], Step [160/469], Reconst Loss: 84.2276, KL Div: 22.2909, Entropy: 0.2404
# Epoch[5/10], Step [170/469], Reconst Loss: 86.7789, KL Div: 23.2274, Entropy: 0.3961
# Epoch[5/10], Step [180/469], Reconst Loss: 86.9588, KL Div: 22.7299, Entropy: 0.1509
# Epoch[5/10], Step [190/469], Reconst Loss: 88.5678, KL Div: 23.6695, Entropy: 0.3270
# Epoch[5/10], Step [200/469], Reconst Loss: 87.8623, KL Div: 22.3214, Entropy: 0.3341
# Epoch[5/10], Step [210/469], Reconst Loss: 83.8818, KL Div: 22.2215, Entropy: 0.2552
# Epoch[5/10], Step [220/469], Reconst Loss: 86.3955, KL Div: 23.0068, Entropy: 0.4294
# Epoch[5/10], Step [230/469], Reconst Loss: 80.3924, KL Div: 22.7087, Entropy: 0.2282
# Epoch[5/10], Step [240/469], Reconst Loss: 85.8349, KL Div: 22.2908, Entropy: 0.2358
# Epoch[5/10], Step [250/469], Reconst Loss: 82.4567, KL Div: 22.3974, Entropy: 0.2361
# Epoch[5/10], Step [260/469], Reconst Loss: 84.5239, KL Div: 22.6536, Entropy: 0.3554
# Epoch[5/10], Step [270/469], Reconst Loss: 86.9179, KL Div: 23.4847, Entropy: 0.3194
# Epoch[5/10], Step [280/469], Reconst Loss: 85.2446, KL Div: 22.8444, Entropy: 0.2722
# Epoch[5/10], Step [290/469], Reconst Loss: 81.6016, KL Div: 21.9663, Entropy: 0.3798
# Epoch[5/10], Step [300/469], Reconst Loss: 84.6763, KL Div: 22.7654, Entropy: 0.2218
# Epoch[5/10], Step [310/469], Reconst Loss: 87.5686, KL Div: 22.8818, Entropy: 0.2603
# Epoch[5/10], Step [320/469], Reconst Loss: 88.2290, KL Div: 23.3891, Entropy: 0.4805
# Epoch[5/10], Step [330/469], Reconst Loss: 86.1877, KL Div: 23.1974, Entropy: 0.3129
# Epoch[5/10], Step [340/469], Reconst Loss: 87.8594, KL Div: 23.1456, Entropy: 0.2402
# Epoch[5/10], Step [350/469], Reconst Loss: 85.8002, KL Div: 23.0473, Entropy: 0.1988
# Epoch[5/10], Step [360/469], Reconst Loss: 86.6164, KL Div: 23.1810, Entropy: 0.2192
# Epoch[5/10], Step [370/469], Reconst Loss: 84.7462, KL Div: 23.0630, Entropy: 0.2688
# Epoch[5/10], Step [380/469], Reconst Loss: 86.9001, KL Div: 23.2851, Entropy: 0.2002
# Epoch[5/10], Step [390/469], Reconst Loss: 86.5696, KL Div: 22.2642, Entropy: 0.4717
# Epoch[5/10], Step [400/469], Reconst Loss: 80.2408, KL Div: 22.1460, Entropy: 0.3105
# Epoch[5/10], Step [410/469], Reconst Loss: 87.4361, KL Div: 22.8114, Entropy: 0.2041
# Epoch[5/10], Step [420/469], Reconst Loss: 87.3087, KL Div: 22.6817, Entropy: 0.2975
# Epoch[5/10], Step [430/469], Reconst Loss: 83.1741, KL Div: 22.5210, Entropy: 0.1510
# Epoch[5/10], Step [440/469], Reconst Loss: 88.0799, KL Div: 22.8092, Entropy: 0.3097
# Epoch[5/10], Step [450/469], Reconst Loss: 84.1322, KL Div: 23.0708, Entropy: 0.1879
# Epoch[5/10], Step [460/469], Reconst Loss: 85.2431, KL Div: 22.5677, Entropy: 0.2912
# Epoch[6/10], Step [10/469], Reconst Loss: 85.1887, KL Div: 22.6718, Entropy: 0.2578
# Epoch[6/10], Step [20/469], Reconst Loss: 84.4663, KL Div: 22.3109, Entropy: 0.2202
# Epoch[6/10], Step [30/469], Reconst Loss: 82.1006, KL Div: 22.5127, Entropy: 0.3885
# Epoch[6/10], Step [40/469], Reconst Loss: 82.9237, KL Div: 23.0596, Entropy: 0.2232
# Epoch[6/10], Step [50/469], Reconst Loss: 84.6568, KL Div: 22.9129, Entropy: 0.3182
# Epoch[6/10], Step [60/469], Reconst Loss: 84.1330, KL Div: 22.2509, Entropy: 0.4203
# Epoch[6/10], Step [70/469], Reconst Loss: 84.0574, KL Div: 22.8919, Entropy: 0.2615
# Epoch[6/10], Step [80/469], Reconst Loss: 85.4894, KL Div: 22.5614, Entropy: 0.4190
# Epoch[6/10], Step [90/469], Reconst Loss: 86.3421, KL Div: 22.8655, Entropy: 0.2503
# Epoch[6/10], Step [100/469], Reconst Loss: 83.7605, KL Div: 23.4715, Entropy: 0.2015
# Epoch[6/10], Step [110/469], Reconst Loss: 82.6915, KL Div: 21.9157, Entropy: 0.2573
# Epoch[6/10], Step [120/469], Reconst Loss: 86.9225, KL Div: 23.2545, Entropy: 0.1456
# Epoch[6/10], Step [130/469], Reconst Loss: 78.9611, KL Div: 22.5257, Entropy: 0.2444
# Epoch[6/10], Step [140/469], Reconst Loss: 86.0293, KL Div: 22.1906, Entropy: 0.2155
# Epoch[6/10], Step [150/469], Reconst Loss: 79.6506, KL Div: 22.6238, Entropy: 0.3145
# Epoch[6/10], Step [160/469], Reconst Loss: 84.7536, KL Div: 22.8643, Entropy: 0.1638
# Epoch[6/10], Step [170/469], Reconst Loss: 84.3623, KL Div: 22.7790, Entropy: 0.1878
# Epoch[6/10], Step [180/469], Reconst Loss: 89.2089, KL Div: 23.0212, Entropy: 0.1974
# Epoch[6/10], Step [190/469], Reconst Loss: 82.5591, KL Div: 22.6730, Entropy: 0.1415
# Epoch[6/10], Step [200/469], Reconst Loss: 80.5143, KL Div: 22.7021, Entropy: 0.1257
# Epoch[6/10], Step [210/469], Reconst Loss: 85.1302, KL Div: 22.2077, Entropy: 0.1776
# Epoch[6/10], Step [220/469], Reconst Loss: 84.5010, KL Div: 23.8524, Entropy: 0.2826
# Epoch[6/10], Step [230/469], Reconst Loss: 85.8084, KL Div: 22.7799, Entropy: 0.2666
# Epoch[6/10], Step [240/469], Reconst Loss: 82.5113, KL Div: 22.6220, Entropy: 0.4314
# Epoch[6/10], Step [250/469], Reconst Loss: 81.4032, KL Div: 22.0148, Entropy: 0.2628
# Epoch[6/10], Step [260/469], Reconst Loss: 84.8330, KL Div: 22.5737, Entropy: 0.1365
# Epoch[6/10], Step [270/469], Reconst Loss: 79.5349, KL Div: 22.3385, Entropy: 0.2194
# Epoch[6/10], Step [280/469], Reconst Loss: 82.7701, KL Div: 22.6157, Entropy: 0.2919
# Epoch[6/10], Step [290/469], Reconst Loss: 85.3061, KL Div: 22.8020, Entropy: 0.2995
# Epoch[6/10], Step [300/469], Reconst Loss: 83.4939, KL Div: 22.8104, Entropy: 0.3885
# Epoch[6/10], Step [310/469], Reconst Loss: 82.0337, KL Div: 22.4286, Entropy: 0.3219
# Epoch[6/10], Step [320/469], Reconst Loss: 83.3710, KL Div: 22.5042, Entropy: 0.2086
# Epoch[6/10], Step [330/469], Reconst Loss: 82.0417, KL Div: 23.2585, Entropy: 0.3045
# Epoch[6/10], Step [340/469], Reconst Loss: 86.3172, KL Div: 23.4892, Entropy: 0.2383
# Epoch[6/10], Step [350/469], Reconst Loss: 83.5200, KL Div: 23.7919, Entropy: 0.2073
# Epoch[6/10], Step [360/469], Reconst Loss: 86.1523, KL Div: 23.4851, Entropy: 0.2343
# Epoch[6/10], Step [370/469], Reconst Loss: 84.8385, KL Div: 22.7174, Entropy: 0.3038
# Epoch[6/10], Step [380/469], Reconst Loss: 82.1449, KL Div: 22.7783, Entropy: 0.4032
# Epoch[6/10], Step [390/469], Reconst Loss: 82.3161, KL Div: 22.6302, Entropy: 0.2581
# Epoch[6/10], Step [400/469], Reconst Loss: 86.6425, KL Div: 23.4394, Entropy: 0.6185
# Epoch[6/10], Step [410/469], Reconst Loss: 81.7924, KL Div: 22.1789, Entropy: 0.4128
# Epoch[6/10], Step [420/469], Reconst Loss: 84.6502, KL Div: 22.5438, Entropy: 0.2767
# Epoch[6/10], Step [430/469], Reconst Loss: 80.2693, KL Div: 22.5200, Entropy: 0.3075
# Epoch[6/10], Step [440/469], Reconst Loss: 81.5760, KL Div: 22.7330, Entropy: 0.1460
# Epoch[6/10], Step [450/469], Reconst Loss: 83.6907, KL Div: 22.2413, Entropy: 0.3809
# Epoch[6/10], Step [460/469], Reconst Loss: 82.8960, KL Div: 22.8857, Entropy: 0.3613
# Epoch[7/10], Step [10/469], Reconst Loss: 85.0378, KL Div: 23.1161, Entropy: 0.2524
# Epoch[7/10], Step [20/469], Reconst Loss: 82.0001, KL Div: 21.7491, Entropy: 0.1485
# Epoch[7/10], Step [30/469], Reconst Loss: 84.0322, KL Div: 23.1031, Entropy: 0.3321
# Epoch[7/10], Step [40/469], Reconst Loss: 84.5196, KL Div: 22.9072, Entropy: 0.2966
# Epoch[7/10], Step [50/469], Reconst Loss: 83.2107, KL Div: 23.2067, Entropy: 0.1915
# Epoch[7/10], Step [60/469], Reconst Loss: 85.6173, KL Div: 23.1883, Entropy: 0.3142
# Epoch[7/10], Step [70/469], Reconst Loss: 81.2515, KL Div: 22.3842, Entropy: 0.2004
# Epoch[7/10], Step [80/469], Reconst Loss: 81.2916, KL Div: 22.4521, Entropy: 0.2483
# Epoch[7/10], Step [90/469], Reconst Loss: 79.7912, KL Div: 22.5133, Entropy: 0.1972
# Epoch[7/10], Step [100/469], Reconst Loss: 81.0560, KL Div: 21.8010, Entropy: 0.3212
# Epoch[7/10], Step [110/469], Reconst Loss: 81.5285, KL Div: 22.4566, Entropy: 0.2670
# Epoch[7/10], Step [120/469], Reconst Loss: 83.6302, KL Div: 22.6391, Entropy: 0.2266
# Epoch[7/10], Step [130/469], Reconst Loss: 86.8547, KL Div: 23.1957, Entropy: 0.2765
# Epoch[7/10], Step [140/469], Reconst Loss: 85.6442, KL Div: 23.2592, Entropy: 0.2345
# Epoch[7/10], Step [150/469], Reconst Loss: 82.3114, KL Div: 22.1548, Entropy: 0.2233
# Epoch[7/10], Step [160/469], Reconst Loss: 79.8202, KL Div: 22.9761, Entropy: 0.2499
# Epoch[7/10], Step [170/469], Reconst Loss: 86.9812, KL Div: 23.5806, Entropy: 0.3195
# Epoch[7/10], Step [180/469], Reconst Loss: 82.2633, KL Div: 22.3064, Entropy: 0.3020
# Epoch[7/10], Step [190/469], Reconst Loss: 82.1702, KL Div: 22.4145, Entropy: 0.3126
# Epoch[7/10], Step [200/469], Reconst Loss: 84.2672, KL Div: 22.3378, Entropy: 0.3519
# Epoch[7/10], Step [210/469], Reconst Loss: 82.6345, KL Div: 22.8387, Entropy: 0.3714
# Epoch[7/10], Step [220/469], Reconst Loss: 84.7851, KL Div: 23.3167, Entropy: 0.3628
# Epoch[7/10], Step [230/469], Reconst Loss: 85.6897, KL Div: 23.1189, Entropy: 0.1508
# Epoch[7/10], Step [240/469], Reconst Loss: 82.3403, KL Div: 22.5901, Entropy: 0.3414
# Epoch[7/10], Step [250/469], Reconst Loss: 85.7047, KL Div: 24.2437, Entropy: 0.2883
# Epoch[7/10], Step [260/469], Reconst Loss: 84.1399, KL Div: 22.4671, Entropy: 0.2307
# Epoch[7/10], Step [270/469], Reconst Loss: 81.8967, KL Div: 22.7334, Entropy: 0.2839
# Epoch[7/10], Step [280/469], Reconst Loss: 82.7886, KL Div: 22.7742, Entropy: 0.2904
# Epoch[7/10], Step [290/469], Reconst Loss: 86.4441, KL Div: 22.8818, Entropy: 0.4796
# Epoch[7/10], Step [300/469], Reconst Loss: 84.6181, KL Div: 22.5528, Entropy: 0.2417
# Epoch[7/10], Step [310/469], Reconst Loss: 83.2469, KL Div: 23.1877, Entropy: 0.3143
# Epoch[7/10], Step [320/469], Reconst Loss: 79.7187, KL Div: 22.5640, Entropy: 0.3157
# Epoch[7/10], Step [330/469], Reconst Loss: 76.8804, KL Div: 22.5726, Entropy: 0.3049
# Epoch[7/10], Step [340/469], Reconst Loss: 84.7453, KL Div: 22.1724, Entropy: 0.3258
# Epoch[7/10], Step [350/469], Reconst Loss: 80.6193, KL Div: 23.2525, Entropy: 0.3397
# Epoch[7/10], Step [360/469], Reconst Loss: 81.6858, KL Div: 22.3280, Entropy: 0.1756
# Epoch[7/10], Step [370/469], Reconst Loss: 84.9606, KL Div: 22.7846, Entropy: 0.2574
# Epoch[7/10], Step [380/469], Reconst Loss: 81.3245, KL Div: 22.8342, Entropy: 0.1273
# Epoch[7/10], Step [390/469], Reconst Loss: 82.8772, KL Div: 22.3486, Entropy: 0.1591
# Epoch[7/10], Step [400/469], Reconst Loss: 81.6187, KL Div: 23.2283, Entropy: 0.3225
# Epoch[7/10], Step [410/469], Reconst Loss: 82.5817, KL Div: 21.9390, Entropy: 0.2243
# Epoch[7/10], Step [420/469], Reconst Loss: 78.2689, KL Div: 22.8746, Entropy: 0.2981
# Epoch[7/10], Step [430/469], Reconst Loss: 82.6740, KL Div: 22.6414, Entropy: 0.2322
# Epoch[7/10], Step [440/469], Reconst Loss: 79.1834, KL Div: 22.0857, Entropy: 0.3872
# Epoch[7/10], Step [450/469], Reconst Loss: 82.4228, KL Div: 22.9250, Entropy: 0.1936
# Epoch[7/10], Step [460/469], Reconst Loss: 77.5906, KL Div: 21.8109, Entropy: 0.1333
# Epoch[8/10], Step [10/469], Reconst Loss: 84.7945, KL Div: 22.5404, Entropy: 0.4578
# Epoch[8/10], Step [20/469], Reconst Loss: 84.9198, KL Div: 23.4815, Entropy: 0.3171
# Epoch[8/10], Step [30/469], Reconst Loss: 83.5098, KL Div: 21.2184, Entropy: 0.3662
# Epoch[8/10], Step [40/469], Reconst Loss: 81.6033, KL Div: 23.3235, Entropy: 0.5438
# Epoch[8/10], Step [50/469], Reconst Loss: 83.1734, KL Div: 22.2236, Entropy: 0.3813
# Epoch[8/10], Step [60/469], Reconst Loss: 82.2879, KL Div: 23.3355, Entropy: 0.2558
# Epoch[8/10], Step [70/469], Reconst Loss: 86.2356, KL Div: 23.1680, Entropy: 0.2858
# Epoch[8/10], Step [80/469], Reconst Loss: 81.5156, KL Div: 23.2185, Entropy: 0.2123
# Epoch[8/10], Step [90/469], Reconst Loss: 80.9270, KL Div: 22.5631, Entropy: 0.1353
# Epoch[8/10], Step [100/469], Reconst Loss: 83.9922, KL Div: 23.0177, Entropy: 0.3177
# Epoch[8/10], Step [110/469], Reconst Loss: 82.2920, KL Div: 22.2614, Entropy: 0.1778
# Epoch[8/10], Step [120/469], Reconst Loss: 84.3853, KL Div: 22.4671, Entropy: 0.3779
# Epoch[8/10], Step [130/469], Reconst Loss: 80.2133, KL Div: 22.2326, Entropy: 0.2362
# Epoch[8/10], Step [140/469], Reconst Loss: 78.8568, KL Div: 22.4844, Entropy: 0.2093
# Epoch[8/10], Step [150/469], Reconst Loss: 81.9923, KL Div: 22.9724, Entropy: 0.2017
# Epoch[8/10], Step [160/469], Reconst Loss: 80.5735, KL Div: 22.2654, Entropy: 0.2894
# Epoch[8/10], Step [170/469], Reconst Loss: 83.0014, KL Div: 22.6182, Entropy: 0.2776
# Epoch[8/10], Step [180/469], Reconst Loss: 83.8115, KL Div: 23.3704, Entropy: 0.2859
# Epoch[8/10], Step [190/469], Reconst Loss: 81.1976, KL Div: 22.6282, Entropy: 0.3476
# Epoch[8/10], Step [200/469], Reconst Loss: 83.2072, KL Div: 23.3170, Entropy: 0.2731
# Epoch[8/10], Step [210/469], Reconst Loss: 80.8412, KL Div: 22.0600, Entropy: 0.1922
# Epoch[8/10], Step [220/469], Reconst Loss: 81.2759, KL Div: 23.0624, Entropy: 0.1681
# Epoch[8/10], Step [230/469], Reconst Loss: 84.9747, KL Div: 23.0640, Entropy: 0.1870
# Epoch[8/10], Step [240/469], Reconst Loss: 86.0780, KL Div: 22.9745, Entropy: 0.2037
# Epoch[8/10], Step [250/469], Reconst Loss: 81.2538, KL Div: 22.0974, Entropy: 0.2942
# Epoch[8/10], Step [260/469], Reconst Loss: 80.5586, KL Div: 22.9269, Entropy: 0.1896
# Epoch[8/10], Step [270/469], Reconst Loss: 80.3814, KL Div: 22.6876, Entropy: 0.3012
# Epoch[8/10], Step [280/469], Reconst Loss: 79.3787, KL Div: 22.7787, Entropy: 0.1903
# Epoch[8/10], Step [290/469], Reconst Loss: 79.8342, KL Div: 22.6730, Entropy: 0.2863
# Epoch[8/10], Step [300/469], Reconst Loss: 80.2106, KL Div: 23.2300, Entropy: 0.2010
# Epoch[8/10], Step [310/469], Reconst Loss: 84.8852, KL Div: 23.1156, Entropy: 0.3593
# Epoch[8/10], Step [320/469], Reconst Loss: 82.1465, KL Div: 22.9153, Entropy: 0.1873
# Epoch[8/10], Step [330/469], Reconst Loss: 81.0179, KL Div: 22.5248, Entropy: 0.1851
# Epoch[8/10], Step [340/469], Reconst Loss: 81.9880, KL Div: 23.7388, Entropy: 0.2413
# Epoch[8/10], Step [350/469], Reconst Loss: 85.4536, KL Div: 23.5344, Entropy: 0.2757
# Epoch[8/10], Step [360/469], Reconst Loss: 82.2330, KL Div: 23.3696, Entropy: 0.2185
# Epoch[8/10], Step [370/469], Reconst Loss: 80.3167, KL Div: 22.3503, Entropy: 0.3278
# Epoch[8/10], Step [380/469], Reconst Loss: 80.8714, KL Div: 22.8727, Entropy: 0.2405
# Epoch[8/10], Step [390/469], Reconst Loss: 83.5398, KL Div: 22.2322, Entropy: 0.2987
# Epoch[8/10], Step [400/469], Reconst Loss: 82.5825, KL Div: 22.5533, Entropy: 0.2465
# Epoch[8/10], Step [410/469], Reconst Loss: 79.4516, KL Div: 22.9927, Entropy: 0.2325
# Epoch[8/10], Step [420/469], Reconst Loss: 81.2209, KL Div: 22.3741, Entropy: 0.4063
# Epoch[8/10], Step [430/469], Reconst Loss: 79.7007, KL Div: 22.0438, Entropy: 0.2745
# Epoch[8/10], Step [440/469], Reconst Loss: 83.5498, KL Div: 22.3280, Entropy: 0.2569
# Epoch[8/10], Step [450/469], Reconst Loss: 84.7100, KL Div: 22.2143, Entropy: 0.2761
# Epoch[8/10], Step [460/469], Reconst Loss: 80.6809, KL Div: 23.1731, Entropy: 0.1462
# Epoch[9/10], Step [10/469], Reconst Loss: 83.8406, KL Div: 24.5106, Entropy: 0.2005
# Epoch[9/10], Step [20/469], Reconst Loss: 81.7211, KL Div: 21.8046, Entropy: 0.1732
# Epoch[9/10], Step [30/469], Reconst Loss: 79.4932, KL Div: 22.8744, Entropy: 0.3081
# Epoch[9/10], Step [40/469], Reconst Loss: 83.0449, KL Div: 22.0242, Entropy: 0.2796
# Epoch[9/10], Step [50/469], Reconst Loss: 83.1428, KL Div: 22.8711, Entropy: 0.2764
# Epoch[9/10], Step [60/469], Reconst Loss: 80.7187, KL Div: 22.7563, Entropy: 0.2443
# Epoch[9/10], Step [70/469], Reconst Loss: 83.2174, KL Div: 22.9279, Entropy: 0.4948
# Epoch[9/10], Step [80/469], Reconst Loss: 80.3918, KL Div: 23.5835, Entropy: 0.2698
# Epoch[9/10], Step [90/469], Reconst Loss: 82.3696, KL Div: 22.0037, Entropy: 0.2727
# Epoch[9/10], Step [100/469], Reconst Loss: 80.4196, KL Div: 22.3534, Entropy: 0.3551
# Epoch[9/10], Step [110/469], Reconst Loss: 78.6748, KL Div: 23.0321, Entropy: 0.1962
# Epoch[9/10], Step [120/469], Reconst Loss: 80.4162, KL Div: 22.5123, Entropy: 0.2480
# Epoch[9/10], Step [130/469], Reconst Loss: 82.8241, KL Div: 21.8836, Entropy: 0.1735
# Epoch[9/10], Step [140/469], Reconst Loss: 82.5392, KL Div: 23.2483, Entropy: 0.1272
# Epoch[9/10], Step [150/469], Reconst Loss: 82.4529, KL Div: 23.0755, Entropy: 0.1752
# Epoch[9/10], Step [160/469], Reconst Loss: 78.0005, KL Div: 21.8267, Entropy: 0.2516
# Epoch[9/10], Step [170/469], Reconst Loss: 80.7352, KL Div: 22.3180, Entropy: 0.1962
# Epoch[9/10], Step [180/469], Reconst Loss: 78.4556, KL Div: 21.9134, Entropy: 0.2483
# Epoch[9/10], Step [190/469], Reconst Loss: 87.4934, KL Div: 23.9318, Entropy: 0.1856
# Epoch[9/10], Step [200/469], Reconst Loss: 82.3580, KL Div: 23.1650, Entropy: 0.2332
# Epoch[9/10], Step [210/469], Reconst Loss: 86.1656, KL Div: 22.8626, Entropy: 0.1927
# Epoch[9/10], Step [220/469], Reconst Loss: 79.4096, KL Div: 23.3841, Entropy: 0.1930
# Epoch[9/10], Step [230/469], Reconst Loss: 80.7158, KL Div: 22.4892, Entropy: 0.1838
# Epoch[9/10], Step [240/469], Reconst Loss: 82.1273, KL Div: 23.4051, Entropy: 0.2851
# Epoch[9/10], Step [250/469], Reconst Loss: 80.8510, KL Div: 23.4050, Entropy: 0.3061
# Epoch[9/10], Step [260/469], Reconst Loss: 80.1492, KL Div: 22.3939, Entropy: 0.3709
# Epoch[9/10], Step [270/469], Reconst Loss: 83.3817, KL Div: 22.7491, Entropy: 0.2728
# Epoch[9/10], Step [280/469], Reconst Loss: 81.7599, KL Div: 22.0695, Entropy: 0.2615
# Epoch[9/10], Step [290/469], Reconst Loss: 84.4734, KL Div: 23.2825, Entropy: 0.2425
# Epoch[9/10], Step [300/469], Reconst Loss: 83.0272, KL Div: 22.9444, Entropy: 0.1305
# Epoch[9/10], Step [310/469], Reconst Loss: 83.9526, KL Div: 23.2490, Entropy: 0.1842
# Epoch[9/10], Step [320/469], Reconst Loss: 84.7881, KL Div: 22.0223, Entropy: 0.3198
# Epoch[9/10], Step [330/469], Reconst Loss: 80.9459, KL Div: 23.0109, Entropy: 0.1900
# Epoch[9/10], Step [340/469], Reconst Loss: 83.7413, KL Div: 23.8199, Entropy: 0.2602
# Epoch[9/10], Step [350/469], Reconst Loss: 83.6006, KL Div: 21.9491, Entropy: 0.2206
# Epoch[9/10], Step [360/469], Reconst Loss: 80.9341, KL Div: 22.4405, Entropy: 0.2020
# Epoch[9/10], Step [370/469], Reconst Loss: 83.5592, KL Div: 23.0793, Entropy: 0.3019
# Epoch[9/10], Step [380/469], Reconst Loss: 83.1937, KL Div: 22.7694, Entropy: 0.3103
# Epoch[9/10], Step [390/469], Reconst Loss: 79.5504, KL Div: 22.4594, Entropy: 0.2601
# Epoch[9/10], Step [400/469], Reconst Loss: 78.4769, KL Div: 22.4502, Entropy: 0.2849
# Epoch[9/10], Step [410/469], Reconst Loss: 81.3342, KL Div: 22.0466, Entropy: 0.3362
# Epoch[9/10], Step [420/469], Reconst Loss: 82.8976, KL Div: 23.0416, Entropy: 0.2853
# Epoch[9/10], Step [430/469], Reconst Loss: 81.4748, KL Div: 22.1476, Entropy: 0.3971
# Epoch[9/10], Step [440/469], Reconst Loss: 83.5660, KL Div: 23.0165, Entropy: 0.4750
# Epoch[9/10], Step [450/469], Reconst Loss: 80.0556, KL Div: 22.9390, Entropy: 0.3637
# Epoch[9/10], Step [460/469], Reconst Loss: 82.7743, KL Div: 22.7671, Entropy: 0.3338
# Epoch[10/10], Step [10/469], Reconst Loss: 80.3139, KL Div: 22.1884, Entropy: 0.2704
# Epoch[10/10], Step [20/469], Reconst Loss: 81.2475, KL Div: 22.6751, Entropy: 0.1872
# Epoch[10/10], Step [30/469], Reconst Loss: 81.9879, KL Div: 22.6243, Entropy: 0.1810
# Epoch[10/10], Step [40/469], Reconst Loss: 78.9368, KL Div: 22.5452, Entropy: 0.2830
# Epoch[10/10], Step [50/469], Reconst Loss: 78.1037, KL Div: 22.7276, Entropy: 0.3722
# Epoch[10/10], Step [60/469], Reconst Loss: 80.5607, KL Div: 22.8443, Entropy: 0.3266
# Epoch[10/10], Step [70/469], Reconst Loss: 83.6383, KL Div: 22.7977, Entropy: 0.3332
# Epoch[10/10], Step [80/469], Reconst Loss: 78.7311, KL Div: 22.7291, Entropy: 0.1853
# Epoch[10/10], Step [90/469], Reconst Loss: 82.8995, KL Div: 23.0678, Entropy: 0.2701
# Epoch[10/10], Step [100/469], Reconst Loss: 82.1568, KL Div: 22.3471, Entropy: 0.2670
# Epoch[10/10], Step [110/469], Reconst Loss: 81.9487, KL Div: 22.9466, Entropy: 0.2616
# Epoch[10/10], Step [120/469], Reconst Loss: 81.4907, KL Div: 22.5450, Entropy: 0.2089
# Epoch[10/10], Step [130/469], Reconst Loss: 85.4850, KL Div: 23.9859, Entropy: 0.4588
# Epoch[10/10], Step [140/469], Reconst Loss: 80.3310, KL Div: 22.8460, Entropy: 0.1198
# Epoch[10/10], Step [150/469], Reconst Loss: 80.8560, KL Div: 22.9243, Entropy: 0.3447
# Epoch[10/10], Step [160/469], Reconst Loss: 81.3646, KL Div: 22.6422, Entropy: 0.1789
# Epoch[10/10], Step [170/469], Reconst Loss: 87.4874, KL Div: 23.6577, Entropy: 0.2490
# Epoch[10/10], Step [180/469], Reconst Loss: 81.4829, KL Div: 22.6445, Entropy: 0.2703
# Epoch[10/10], Step [190/469], Reconst Loss: 83.1508, KL Div: 23.4930, Entropy: 0.3161
# Epoch[10/10], Step [200/469], Reconst Loss: 77.8927, KL Div: 22.2756, Entropy: 0.1434
# Epoch[10/10], Step [210/469], Reconst Loss: 81.5096, KL Div: 22.6485, Entropy: 0.3802
# Epoch[10/10], Step [220/469], Reconst Loss: 76.1973, KL Div: 23.1274, Entropy: 0.2907
# Epoch[10/10], Step [230/469], Reconst Loss: 83.4753, KL Div: 22.2979, Entropy: 0.1762
# Epoch[10/10], Step [240/469], Reconst Loss: 81.0186, KL Div: 22.5224, Entropy: 0.2181
# Epoch[10/10], Step [250/469], Reconst Loss: 78.7517, KL Div: 22.5389, Entropy: 0.2359
# Epoch[10/10], Step [260/469], Reconst Loss: 84.7088, KL Div: 22.7467, Entropy: 0.2779
# Epoch[10/10], Step [270/469], Reconst Loss: 81.2013, KL Div: 23.7914, Entropy: 0.1063
# Epoch[10/10], Step [280/469], Reconst Loss: 83.2912, KL Div: 22.2326, Entropy: 0.3415
# Epoch[10/10], Step [290/469], Reconst Loss: 83.9106, KL Div: 23.3952, Entropy: 0.3155
# Epoch[10/10], Step [300/469], Reconst Loss: 82.2305, KL Div: 23.4005, Entropy: 0.1359
# Epoch[10/10], Step [310/469], Reconst Loss: 76.9440, KL Div: 22.0934, Entropy: 0.1396
# Epoch[10/10], Step [320/469], Reconst Loss: 80.9190, KL Div: 22.7023, Entropy: 0.2055
# Epoch[10/10], Step [330/469], Reconst Loss: 84.1886, KL Div: 22.4064, Entropy: 0.4062
# Epoch[10/10], Step [340/469], Reconst Loss: 80.0180, KL Div: 22.3217, Entropy: 0.2232
# Epoch[10/10], Step [350/469], Reconst Loss: 80.4234, KL Div: 22.5432, Entropy: 0.1820
# Epoch[10/10], Step [360/469], Reconst Loss: 80.5904, KL Div: 22.5785, Entropy: 0.2424
# Epoch[10/10], Step [370/469], Reconst Loss: 77.3906, KL Div: 22.9713, Entropy: 0.1896
# Epoch[10/10], Step [380/469], Reconst Loss: 81.9792, KL Div: 22.2141, Entropy: 0.2460
# Epoch[10/10], Step [390/469], Reconst Loss: 81.5035, KL Div: 22.6235, Entropy: 0.3317
# Epoch[10/10], Step [400/469], Reconst Loss: 81.7981, KL Div: 22.2052, Entropy: 0.3934
# Epoch[10/10], Step [410/469], Reconst Loss: 79.7859, KL Div: 22.5462, Entropy: 0.3444
# Epoch[10/10], Step [420/469], Reconst Loss: 79.7276, KL Div: 22.7004, Entropy: 0.2594
# Epoch[10/10], Step [430/469], Reconst Loss: 79.5776, KL Div: 21.8020, Entropy: 0.2837
# Epoch[10/10], Step [440/469], Reconst Loss: 81.0135, KL Div: 22.2785, Entropy: 0.3044
# Epoch[10/10], Step [450/469], Reconst Loss: 77.7556, KL Div: 22.6364, Entropy: 0.1075
# Epoch[10/10], Step [460/469], Reconst Loss: 83.4085, KL Div: 21.8380, Entropy: 0.2441

# %%
x,_ = next(iter(data_loader))
x = x[:24,:,:,:].to(device)
out, _, _, log_p = model_G(x.view(-1, image_size)) 
x_concat = torch.cat([x.view(-1, 1, 28, 28), out.view(-1, 1, 28, 28)], dim=3)
out_grid = torchvision.utils.make_grid(x_concat).cpu().data
show(out_grid)

# %% [markdown]
# This was for reconstruction, but we care more about generation. For each category, we are generating 8 samples thanks to the following matrix, so that in the end, we should have on each line only one digit represented.

# %%
matrix = np.zeros((8,n_classes))
matrix[:,0] = 1
final = matrix[:]
for i in range(1,n_classes):
    final = np.vstack((final,np.roll(matrix,i)))

# %%
with torch.no_grad():
        z = torch.randn(8*n_classes, z_dim).to(device)
        y_onehot = torch.tensor(final).type(torch.FloatTensor).to(device)
        out = model_G.decode(z,y_onehot).view(-1, 1, 28, 28)

out_grid = torchvision.utils.make_grid(out).cpu()
show(out_grid)

# %% [markdown]
# It does not look like our original idea is working...
#
# To check that our network is not using the categorical variable, we can track the [normalized mutual information](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.normalized_mutual_info_score.html) between the true labels and the labels 'predicted' by our network (just by taking the category with maximal probability). Change your training loop to return the normalized mutual information (NMI) for each epoch. Plot the curve to check that the NMI is actually decreasing.

# %% [markdown]
# In order to force our network to use the categorical variable, we will change the loss following this ICLR [paper](https://openreview.net/forum?id=Sy2fzU9gl)
#
# Implement this change in the training loop and plot the new NMI curve after 10 epochs. For $\beta = 20$, you should see that NMI increases. But reconstruction starts to be bad and generation is still poor.
#
# This is explained in this [paper](https://arxiv.org/abs/1804.03599) and a solution is proposed see Section 5. Implement the solution described in Section 3 equation (7) if the NIPS [paper](https://arxiv.org/abs/1804.00104)

# %%
model_G = VAE_Gumbel().to(device)
optimizer = torch.optim.Adam(model_G.parameters(), lr=learning_rate)

# %%
def train_G_modified_loss(model, data_loader=data_loader,num_epochs=num_epochs, beta , C_z_fin, C_c_fin, verbose=True):
    
    # your code here
    reconst_loss = F.binary_cross_entropy(x_reconst, x, reduction='sum')

# %%
with torch.no_grad():
        z = torch.randn(8*n_classes, z_dim).to(device)
        y_onehot = torch.tensor(final).type(torch.FloatTensor).to(device)
        out = model_G.decode(z,y_onehot).view(-1, 1, 28, 28)
out_grid = torchvision.utils.make_grid(out).cpu()
show(out_grid)

# %%
i = 1
with torch.no_grad():
    plt.plot()
    z = torch.randn(8, z_dim).to(device)
    y_onehot = torch.tensor(np.roll(matrix,i)).type(torch.FloatTensor).to(device)
    out = model_G.decode(z,y_onehot).view(-1, 1, 28, 28)
    out_grid = torchvision.utils.make_grid(out).cpu()
    show(out_grid)

# %%
x,_ = next(iter(data_loader))
x = x[:24,:,:,:].to(device)
out, _, _, log_p = model_G(x.view(-1, image_size)) 
x_concat = torch.cat([x.view(-1, 1, 28, 28), out.view(-1, 1, 28, 28)], dim=3)
out_grid = torchvision.utils.make_grid(x_concat).cpu().data
show(out_grid)
